# %% [markdown]
# # Logistics for Healthcare project

# %% [markdown]
# ### DATA CLOUD SPACE SET UP: FIREBASE

# %%
# --Importing necessary libraries databsase setup: firebase. 
import firebase_admin
from firebase_admin import credentials, firestore
from datetime import datetime
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)

# Initialize Firebase
cred = credentials.Certificate('healthy-healthcare-firebase-adminsdk-fbsvc-05315e3efc.json')
if not firebase_admin._apps:
    firebase_admin.initialize_app(cred)
db = firestore.client()

# Initial data for facilities
FACILITIES = {
    "Arnhem": {
        "General Practitioner": 1800,
        "Geriatric Rehabilitation": 800,
        "Short-Term Residential Care": 850,
        "Crisis Admission": 750,
        "Clinical Ward": 800,
        "Acute Admission Unit": 700,
        "Emergency Department": 900,
        "Nursing Home": 4000
    },
    "Nijmegen": {
        "General Practitioner": 533,
        "Geriatric Rehabilitation": 400,
        "Short-Term Residential Care": 450,
        "Crisis Admission": 500,
        "Clinical Ward": 450,
        "Acute Admission Unit": 400,
        "Emergency Department": 600,
        "Nursing Home": 3000
    }
}

def initialize_cloud_space():
    base_date = datetime(2025, 5, 1)
    week_date = base_date.strftime('%Y-%m-%d')
    
    for facility in FACILITIES:
        facility_ref = db.collection('prediction').document(facility)
        facility_ref.set({
            'name': facility,
            'capacities': FACILITIES[facility]
        })
        
        week_ref = facility_ref.collection('weeks').document(f'week_{week_date}')
        week_ref.set({
            'date': week_date,
            'active_patients_data': [],
            'metrics': {},
            'timestamp': firestore.SERVER_TIMESTAMP
        })
        
        logger.info(f"Initialized {facility} for week {week_date}")

if __name__ == "__main__":
    initialize_cloud_space()
    logger.info("Cloud space setup complete")

# %% [markdown]
# ### SIMULATION MODEL INTERGRATE WITH FIREBASE

# %%
# --Importing necessary libraries for simulation--

import simpy
import numpy as np
from collections import defaultdict
import firebase_admin
from firebase_admin import credentials, firestore
from datetime import datetime, timedelta
import logging
from scipy.stats import expon

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger(__name__)
VERBOSE_LOGGING = True #VERBOSE_LOGGING enables detailed debug logs (e.g., state transitions, capacity usage).

# Initialize Firebase
cred = credentials.Certificate('healthy-healthcare-firebase-adminsdk-fbsvc-05315e3efc.json') #Loads Firebase credentials from JSON file
if not firebase_admin._apps:
    firebase_admin.initialize_app(cred)
db = firestore.client()

# Facility capacities for simulation
# These capacities are used to simulate the healthcare system's resource limits each region.
# They are also used to initialize the Firebase database with the initial state of each facility.
FACILITIES = {
    "Arnhem": {
        "General Practitioner": 1800,
        "Geriatric Rehabilitation": 800,
        "Short-Term Residential Care": 850,
        "Crisis Admission": 750,
        "Clinical Ward": 800,
        "Acute Admission Unit": 700,
        "Emergency Department": 900,
        "Nursing Home": 4000
    },
    "Nijmegen": {
        "General Practitioner": 533,
        "Geriatric Rehabilitation": 400,
        "Short-Term Residential Care": 450,
        "Crisis Admission": 500,
        "Clinical Ward": 450,
        "Acute Admission Unit": 400,
        "Emergency Department": 600,
        "Nursing Home": 3000
    }
}

# Valid states for simulation
# These states represent the different stages a patient can be in during their healthcare journey.
# Discharge and Passed Away are terminal; others are active stages.
# Awaiting Nursing Home (W2) represents the wait for Nursing Home (W2 period, mean 96 hours).
# W1 is not a state but a wait within Home (mean 48 hours).
VALID_STATES = {
    "Home",
    "General Practitioner",
    "Geriatric Rehabilitation",
    "Short-Term Residential Care",
    "Crisis Admission",
    "Awaiting Nursing Home (W2)",
    "Clinical Ward",
    "Acute Admission Unit",
    "Emergency Department",
    "Nursing Home",
    "Discharge",
    "Passed Away"
}

# Simulation Parameters
TOTAL_SIMULATION_WEEKS = 56
NUM_NEW_PATIENTS_PER_WEEK = {"Arnhem": 300, "Nijmegen": 250}  # Fixed new patients per week for each region. This + the count of active patients (fetch from Firebase) determines the total number of patients in the simulation.
SIM_TIME_PER_WEEK = 28 * 24
W1_MEAN = 48
W2_MEAN = 96

# Probabilities and durations for various healthcare processes
# These probabilities and durations are used to simulate patient transitions between states.
PASS_AWAY_PROB = 0.02
TRANSFER_PROB = 0.3
EMERGENCY_PROB = 0.4
ED_PROB_DISCHARGE_HOME = 0.1
ED_PROB_TO_STC = 0.25

# Stay durations in hours for various states
NURSING_HOME_STAY_MIN_HOURS = 6 * 30 * 24
NURSING_HOME_STAY_MAX_HOURS = 3 * 12 * 30 * 24
ED_STC_TARGET_OPTIONS = ["Crisis Admission", "Short-Term Residential Care", "Geriatric Rehabilitation"]
ED_STC_ADMISSION_WAIT_MIN_HOURS = 2
ED_STC_ADMISSION_WAIT_MAX_HOURS = 12
GP_CONSULT_MIN_HOURS = 0.25
GP_CONSULT_MAX_HOURS = 1
STC_STAY_MIN_HOURS = 72
STC_STAY_MAX_HOURS = 120
STC_TRANSFER_MIN_HOURS = 6
STC_TRANSFER_MAX_HOURS = 12
CW_STAY_MIN_HOURS = 48
CW_STAY_MAX_HOURS = 120
AAU_STAY_MIN_HOURS = 48
AAU_STAY_MAX_HOURS = 120
ED_STAY_MIN_HOURS = 24
ED_STAY_MAX_HOURS = 48
CW_ADMISSION_WAIT_MIN_HOURS = 2  
CW_ADMISSION_WAIT_MAX_HOURS = 12
AAU_ADMISSION_WAIT_MIN_HOURS = 2  
AAU_ADMISSION_WAIT_MAX_HOURS = 12
ED_ADMISSION_WAIT_MIN_HOURS = 2  
ED_ADMISSION_WAIT_MAX_HOURS = 12

# Stats Class
# The Stats class tracks simulation metrics, including occupancy, wait times, and new exit predictions.
class Stats:
    def __init__(self, env, resources, week_number, facility, capacities, active_patients_counts):
        self.env = env # SimPy environment.
        self.resources = resources # SimPy resources (beds per stage).
        self.week_number = week_number # Current week (e.g., 1 for 2025-05-01)
        self.facility = facility # Facility name (each region) (e.g., "Arnhem" or "Nijmegen").
        self.capacities = capacities # Bed capacities (from prediction or FACILITIES).
        self.active_patients_counts = active_patients_counts # Counts from real-time data (e.g., {"Nursing Home": 60}).

        # Attributes to track simulation metrics
        self.state_visits = defaultdict(int) # Counts visits to each stage.
        self.state_times = defaultdict(list) # Lists durations spent in each stage (within week)
        self.wait_elv_times = [] # Wait times for Geriatric Rehabilitation, Short-Term Residential Care.
        self.wait_crisis_times = [] # Wait times for Crisis Admission.
        self.wait_cw_times = [] # Wait times for Clinical Ward. 
        self.wait_aau_times = [] # Wait times for Acute Admission Unit.
        self.wait_ed_times = [] # Wait times for Emergency Department.
        self.wait_w2_times = [] # Wait times for Awaiting Nursing Home (W2).
        self.capacity_usage = defaultdict(float) # Tracks bed usage for occupancy metrics.
        self.capacity_counts = defaultdict(int) # Tracks bed usage for occupancy metrics.

# Do we need to track wait times for other states like Clinical Ward, Acute Admission Unit, Emergency Department?

        # Expected durations (in hours) and exit probabilities
        self.expected_durations = {                                       # Average stay durations per stage (in hours)
            "Home": W1_MEAN,  # Exponential
            "General Practitioner": np.mean([GP_CONSULT_MIN_HOURS, GP_CONSULT_MAX_HOURS]),  # Uniform
            "Geriatric Rehabilitation": np.mean([STC_STAY_MIN_HOURS, STC_STAY_MAX_HOURS]),
            "Short-Term Residential Care": np.mean([STC_STAY_MIN_HOURS, STC_STAY_MAX_HOURS]),
            "Crisis Admission": np.mean([STC_STAY_MIN_HOURS, STC_STAY_MAX_HOURS]),
            "Awaiting Nursing Home (W2)": W2_MEAN,  # Exponential
            "Clinical Ward": np.mean([CW_STAY_MIN_HOURS, CW_STAY_MAX_HOURS]),
            "Acute Admission Unit": np.mean([AAU_STAY_MIN_HOURS, AAU_STAY_MAX_HOURS]),
            "Emergency Department": np.mean([ED_STAY_MIN_HOURS, ED_STAY_MAX_HOURS]),
            "Nursing Home": np.mean([NURSING_HOME_STAY_MIN_HOURS, NURSING_HOME_STAY_MAX_HOURS])
        }
        self.exit_probabilities = self.calculate_exit_probabilities() 
        self.env.process(self.monitor_capacity())
# Calculate Exit Probabilities (a solution to tackle the issue of patients tracking duration stay of each patients that are updated from Firebase)
    def calculate_exit_probabilities(self): # P(stay ≤ 168 hours) per stage
        """Calculate probability of exiting each stage within one week (168 hours)."""
        week_hours = SIM_TIME_PER_WEEK
        probs = {}
        for state in VALID_STATES - {"Discharge", "Passed Away"}:
            if state == "Home":
                probs[state] = 1 - expon.cdf(week_hours, scale=W1_MEAN)
            elif state == "General Practitioner":
                min_h, max_h = GP_CONSULT_MIN_HOURS, GP_CONSULT_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
            elif state in ["Geriatric Rehabilitation", "Short-Term Residential Care", "Crisis Admission"]:
                min_h, max_h = STC_STAY_MIN_HOURS, STC_STAY_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
            elif state == "Awaiting Nursing Home (W2)":
                probs[state] = 1 - expon.cdf(week_hours, scale=W2_MEAN)
            elif state == "Clinical Ward":
                min_h, max_h = CW_STAY_MIN_HOURS, CW_STAY_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
            elif state == "Acute Admission Unit":
                min_h, max_h = AAU_STAY_MIN_HOURS, AAU_STAY_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
            elif state == "Emergency Department":
                min_h, max_h = ED_STAY_MIN_HOURS, ED_STAY_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
            elif state == "Nursing Home":
                min_h, max_h = NURSING_HOME_STAY_MIN_HOURS, NURSING_HOME_STAY_MAX_HOURS
                probs[state] = (week_hours - min_h) / (max_h - min_h) if min_h <= week_hours <= max_h else 1 if week_hours > max_h else 0
        return probs

# Record Visits, Time, and Transitions
    # These methods are used to log visits to states, time spent in states, and transitions between states.
    def record_visit(self, state):
        self.state_visits[state] += 1
        if VERBOSE_LOGGING:
            logger.debug(f"{self.facility} Week {self.week_number}: Visit to {state}")

    def record_time(self, state, duration):
        if duration > 0.001:
            self.state_times[state].append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: Time in {state}: {duration:.2f} hours")

    def record_transition(self, from_state, to_state, duration):
        if to_state in ["Geriatric Rehabilitation", "Short-Term Residential Care"]:
            self.wait_elv_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: ELV wait time: {duration:.2f} hours")
        elif to_state == "Crisis Admission":
            self.wait_crisis_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: Crisis wait time: {duration:.2f} hours")
        elif to_state == "Clinical Ward":
            self.wait_cw_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: Clinical Ward wait time: {duration:.2f} hours")
        elif to_state == "Acute Admission Unit":
            self.wait_aau_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: Acute Admission wait time: {duration:.2f} hours")
        elif to_state == "Emergency Department":
            self.wait_ed_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: Emergency Department wait time: {duration:.2f} hours")
        elif to_state == "Nursing Home":  
            self.wait_w2_times.append(duration)
            if VERBOSE_LOGGING:
                logger.debug(f"{self.facility} Week {self.week_number}: W2 wait time: {duration:.2f} hours")

# Monitor Capacity Usage    
    # This method monitors the usage of resources (beds) in each state every 12 hours.
    # Used for occupancy metrics (e.g., OCC_NH).
    def monitor_capacity(self):
        while True:
            for state_name, resource_obj in self.resources.items():
                if state_name in self.capacities:
                    usage = len(resource_obj.users)
                    self.capacity_usage[state_name] += usage
                    self.capacity_counts[state_name] += 1
                    if VERBOSE_LOGGING and usage > 0:
                        logger.debug(f"{self.facility} Week {self.week_number}: {state_name} usage: {usage}/{self.capacities[state_name]}")
            yield self.env.timeout(12)

# Get Metrics 
    # This method calculates and returns various metrics for the week, including occupancy rates, wait times, expected durations, and expected exits.
    # It returns a dictionary of metrics that can be stored in Firebase.
    def get_metrics(self, week_start_date):
        # Beds: beds/available "slots" for each state.
        elv_beds = self.capacities["Geriatric Rehabilitation"] + self.capacities["Short-Term Residential Care"]
        crisis_beds = self.capacities["Crisis Admission"]
        nh_beds = self.capacities["Nursing Home"]
        cw_beds = self.capacities["Clinical Ward"]
        aau_beds = self.capacities["Acute Admission Unit"]
        ed_beds = self.capacities["Emergency Department"]
        # Occupancy: Average usage over counts, divided by capacity
        occ_elv = ((self.capacity_usage["Geriatric Rehabilitation"] + self.capacity_usage["Short-Term Residential Care"]) /
                   (self.capacity_counts["Geriatric Rehabilitation"] + self.capacity_counts["Short-Term Residential Care"])) / elv_beds if (self.capacity_counts["Geriatric Rehabilitation"] + self.capacity_counts["Short-Term Residential Care"]) > 0 else 0
        occ_nh = (self.capacity_usage["Nursing Home"] / self.capacity_counts["Nursing Home"]) / nh_beds if self.capacity_counts["Nursing Home"] > 0 else 0
        occ_cw = (self.capacity_usage["Clinical Ward"] / self.capacity_counts["Clinical Ward"]) / cw_beds if self.capacity_counts["Clinical Ward"] > 0 else 0
        occ_aau = (self.capacity_usage["Acute Admission Unit"] / self.capacity_counts["Acute Admission Unit"]) / aau_beds if self.capacity_counts["Acute Admission Unit"] > 0 else 0
        occ_ed = (self.capacity_usage["Emergency Department"] / self.capacity_counts["Emergency Department"]) / ed_beds if self.capacity_counts["Emergency Department"] > 0 else 0
        occ_crisis = (self.capacity_usage["Crisis Admission"] / self.capacity_counts["Crisis Admission"]) / crisis_beds if self.capacity_counts["Crisis Admission"] > 0 else 0
        # Wait times: Mean of wait_elv_times/wait_crisis_times in days, defaults to W2_MEAN or average wait.
        wait_elv = np.mean(self.wait_elv_times) / 24 if self.wait_elv_times else W2_MEAN / 24
        wait_crisis = np.mean(self.wait_crisis_times) / 24 if self.wait_crisis_times else np.mean([ED_STC_ADMISSION_WAIT_MIN_HOURS, ED_STC_ADMISSION_WAIT_MAX_HOURS]) / 24
        wait_cw = np.mean(self.wait_cw_times) / 24 if self.wait_cw_times else np.mean([CW_ADMISSION_WAIT_MIN_HOURS, CW_ADMISSION_WAIT_MAX_HOURS]) / 24
        wait_aau = np.mean(self.wait_aau_times) / 24 if self.wait_aau_times else np.mean([AAU_ADMISSION_WAIT_MIN_HOURS, AAU_ADMISSION_WAIT_MAX_HOURS]) / 24
        wait_ed = np.mean(self.wait_ed_times) / 24 if self.wait_ed_times else np.mean([ED_ADMISSION_WAIT_MIN_HOURS, ED_ADMISSION_WAIT_MAX_HOURS]) / 24
        wait_w2 = np.mean(self.wait_w2_times) / 24 if self.wait_w2_times else W2_MEAN / 24
        # Expected durations (in days)
        expected_durations = {f"EXPECTED_DURATION_{state.upper().replace(' ', '_')}": duration / 24 for state, duration in self.expected_durations.items()}

        # Expected exits based on active_patients_counts
        expected_exits = {}
        for state in VALID_STATES - {"Discharge", "Passed Away"}:
            count = self.active_patients_counts.get(state, 0)
            prob = self.exit_probabilities.get(state, 0)
            expected_exits[f"EXPECTED_EXITS_{state.upper().replace(' ', '_')}"] = count * prob

        metrics = {
            "MUNICIPALITY": self.facility,
            "DATE": week_start_date,
            "ELVBEDS": elv_beds,
            "CRISISBEDS": crisis_beds,
            "NHBEDS": nh_beds,
            "Clinical Ward Beds": cw_beds,
            "Acute Admission Unit Beds": aau_beds,
            "Emergency Department Beds": ed_beds,
            "WAIT_ELV": float(wait_elv),
            "WAIT_CRISIS": float(wait_crisis),
            "WAIT_CW": float(wait_cw),
            "WAIT_AAU": float(wait_aau),
            "WAIT_ED": float(wait_ed),
            "WAIT_W2": float(wait_w2),
            "OCC_ELV": float(occ_elv),
            "OCC_CRISIS": float(occ_crisis),
            "OCC_NH": float(occ_nh),
            "OCC_CW": float(occ_cw),
            "OCC_AAU": float(occ_aau),
            "OCC_ED": float(occ_ed),
            **expected_durations,
            **expected_exits
        }
        if VERBOSE_LOGGING:
            logger.debug(f"{self.facility} Week {self.week_number}: Capacities - NH: {nh_beds}, ELV: {elv_beds}, Crisis: {crisis_beds}, CW: {cw_beds}, AAU: {aau_beds}, ED: {ed_beds}")
            logger.debug(f"{self.facility} Week {self.week_number}: Metrics: {metrics}")
        return metrics

# Client Class
# The Client class represents a patient in the healthcare system.
class Client:
    def __init__(self, env, client_id, stats, resources, initial_state="Home"):
        self.env = env
        self.id = client_id
        self.state = initial_state
        self.alive = True
        self.stats = stats
        self.state_entry_time = env.now
        self.resources = resources
        self.state_handlers = {
            "Home": self.at_home,
            "General Practitioner": self.at_gp,
            "Geriatric Rehabilitation": self.in_short_term_care,
            "Short-Term Residential Care": self.in_short_term_care,
            "Crisis Admission": self.in_short_term_care,
            "Awaiting Nursing Home (W2)": self.await_nursing_home_w2,
            "Clinical Ward": self.in_clinical_ward,
            "Acute Admission Unit": self.in_acute_admission,
            "Emergency Department": self.in_emergency_dept,
            "Nursing Home": self.in_nursing_home
        }
        self.stats.record_visit(self.state)
        # Initializes a patient with an ID, starting state (default Home), and tracks entry time.
        # state_handlers maps stages to methods (e.g., Home → at_home).

    def run(self):
        while self.alive and self.state not in ["Discharge", "Passed Away"]:
            if self.env.now >= SIM_TIME_PER_WEEK:
                break
            handler = self.state_handlers.get(self.state)
            if handler:
                if self.state in self.resources:
                    with self.resources[self.state].request() as req:
                        yield req
                        yield self.env.process(handler())
                else:
                    yield self.env.process(handler())
            else:
                self.alive = False
                break
    # Runs until the patient dies, is discharged, or the week ends (168 hours).
    # Requests resources (beds) for stages with capacity limits.
    # Executes the stage’s handler method.

    def update_state(self, new_state): # Updates state, records duration, and logs transitions.
        if not self.alive and self.state == "Passed Away" and new_state == "Passed Away": return
        if not self.alive and new_state != "Passed Away": return
        duration = self.env.now - self.state_entry_time
        self.stats.record_time(self.state, duration)
        self.stats.record_transition(self.state, new_state, duration)
        self.state = new_state
        self.state_entry_time = self.env.now
        if self.state == "Passed Away":
            self.alive = False
        else:
            self.stats.record_visit(self.state)
        if VERBOSE_LOGGING:
            logger.debug(f"Client {self.id} in {self.stats.facility}: Transition to {new_state}")

    def _check_pass_away(self, probability, context_state): # Checks if the client passes away based on a probability.
        if self.alive and np.random.random() < probability:
            self.update_state("Passed Away")
            return True
        return False

# Below is how  the Client class methods are structured to handle different states in the healthcare journey.
# Each method simulates the time spent in that state and transitions to the next state based on probabilities and conditions.
# Goes untill # Simulation runner, for the sake of simplicity, we only explain 2 states here as an example, the rest follow a similar pattern.
    def at_home(self): # Either goes to Emergency Department (EMERGENCY_PROB = 0.4) or waits W1 (exponential(48)) then to General Practitioner
        if not self.alive: return
        if np.random.random() < EMERGENCY_PROB:
            ed_wait = np.random.uniform(ED_ADMISSION_WAIT_MIN_HOURS, ED_ADMISSION_WAIT_MAX_HOURS)
            yield self.env.timeout(ed_wait)
            self.update_state("Emergency Department")
        else:
            w1_wait_time = np.random.exponential(W1_MEAN)
            yield self.env.timeout(w1_wait_time)
            if not self.alive: return
            if self._check_pass_away(PASS_AWAY_PROB, "at W1 (waiting for GP)"): return
            self.update_state("General Practitioner")

    def at_gp(self): # Stays for (0.25, 1) hours (stay uniform), then to Short term care (STC) stage (40% Geriatric Rehabilitation, 40% Short-Term Residential Care, 20% Crisis Admission) after wait  (uniform((0, 48)).
        if not self.alive: return
        gp_consult_time = np.random.uniform(GP_CONSULT_MIN_HOURS, GP_CONSULT_MAX_HOURS)
        yield self.env.timeout(gp_consult_time)
        if not self.alive: return
        rand_stc = np.random.random()
        next_stc_type = ("Geriatric Rehabilitation" if rand_stc < 0.4 else
                         "Short-Term Residential Care" if rand_stc < 0.8 else
                         "Crisis Admission")
        stc_admission_wait = np.random.uniform(0, 48)
        yield self.env.timeout(stc_admission_wait)
        if not self.alive: return
        self.update_state(next_stc_type)

    def in_short_term_care(self): 
        if not self.alive: return
        current_stc_type = self.state
        stay_time = np.random.uniform(STC_STAY_MIN_HOURS, STC_STAY_MAX_HOURS)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        if np.random.random() < TRANSFER_PROB:
            options = ["Geriatric Rehabilitation", "Short-Term Residential Care", "Crisis Admission"]
            if current_stc_type in options: options.remove(current_stc_type)
            if options:
                new_stc_type = np.random.choice(options)
                transfer_delay = np.random.uniform(STC_TRANSFER_MIN_HOURS, STC_TRANSFER_MAX_HOURS)
                yield self.env.timeout(transfer_delay)
                if not self.alive: return
                self.update_state(new_stc_type)
                return
        rand_next = np.random.random()
        if rand_next < 0.4:
            cw_wait = np.random.uniform(CW_ADMISSION_WAIT_MIN_HOURS, CW_ADMISSION_WAIT_MAX_HOURS)  # New: Wait before CW
            yield self.env.timeout(cw_wait)
            next_state = "Clinical Ward"
        elif rand_next < 0.7:
            aau_wait = np.random.uniform(AAU_ADMISSION_WAIT_MIN_HOURS, AAU_ADMISSION_WAIT_MAX_HOURS)  # New: Wait before AAU
            yield self.env.timeout(aau_wait)
            next_state = "Acute Admission Unit"
        else:
            ed_wait = np.random.uniform(ED_ADMISSION_WAIT_MIN_HOURS, ED_ADMISSION_WAIT_MAX_HOURS)  # New: Wait before ED
            yield self.env.timeout(ed_wait)
            next_state = "Emergency Department"
        self.update_state(next_state)

    def _handle_post_acute_care_transition(self):
        if not self.alive: return
        self.update_state("Awaiting Nursing Home (W2)")

    def in_clinical_ward(self):
        if not self.alive: return
        stay_time = np.random.uniform(CW_STAY_MIN_HOURS, CW_STAY_MAX_HOURS)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        self._handle_post_acute_care_transition()

    def in_acute_admission(self):
        if not self.alive: return
        stay_time = np.random.uniform(AAU_STAY_MIN_HOURS, AAU_STAY_MAX_HOURS)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        self._handle_post_acute_care_transition()

    def in_emergency_dept(self):
        if not self.alive: return
        stay_time = np.random.uniform(ED_STAY_MIN_HOURS, ED_STAY_MAX_HOURS)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        rand_ed_outcome = np.random.random()
        if rand_ed_outcome < ED_PROB_DISCHARGE_HOME:
            self.update_state("Discharge")
        elif rand_ed_outcome < ED_PROB_DISCHARGE_HOME + ED_PROB_TO_STC:
            if not ED_STC_TARGET_OPTIONS:
                self._handle_post_acute_care_transition()
                return
            chosen_stc_from_ed = np.random.choice(ED_STC_TARGET_OPTIONS)
            stc_admission_wait_from_ed = np.random.uniform(ED_STC_ADMISSION_WAIT_MIN_HOURS, ED_STC_ADMISSION_WAIT_MAX_HOURS)
            yield self.env.timeout(stc_admission_wait_from_ed)
            if not self.alive: return
            self.update_state(chosen_stc_from_ed)
        else:
            self._handle_post_acute_care_transition()

    def await_nursing_home_w2(self):
        if not self.alive: return
        w2_wait_time = np.random.exponential(W2_MEAN)
        yield self.env.timeout(w2_wait_time)
        if not self.alive: return
        self.update_state("Nursing Home")

    def in_nursing_home(self):
        if not self.alive: return
        stay_duration = np.random.uniform(NURSING_HOME_STAY_MIN_HOURS, NURSING_HOME_STAY_MAX_HOURS)
        yield self.env.timeout(stay_duration)
        if not self.alive: return
        self.update_state("Discharge")

# Simulation Runner
def run_one_week_simulation(week_num, active_patients_counts, global_client_id_counter_ref, facility, week_start_date, capacities, new_patients):
    try:
        validated_capacities = {}
        for state, cap in capacities.items():
            expected_cap = FACILITIES[facility].get(state, 1)
            if not isinstance(cap, int) or cap <= 0 or abs(cap - expected_cap) > 0.01 * expected_cap:
                logger.warning(f"Invalid or inconsistent capacity for {state} in {facility}: {cap}. Using {expected_cap}.")
                cap = expected_cap
            validated_capacities[state] = cap
        
        env = simpy.Environment()
        resources = {state: simpy.Resource(env, capacity=cap) for state, cap in validated_capacities.items()}
        stats = Stats(env, resources, week_num, facility, validated_capacities, active_patients_counts)
        current_week_clients = []
        
        # Initialize clients from active_patients_counts
        initial_total = sum(active_patients_counts.values())
        logger.info(f"{facility} Week {week_num}: Initial active patients: {initial_total}")

        for state, count in active_patients_counts.items(): # active_patients_counts: the counts of patients fetched from Firebase for the current week.
            if state not in VALID_STATES or state in ["Discharge", "Passed Away"]:
                if state == "Awaiting Nursing Home":
                    logger.warning(f"Invalid or terminal state {state} in {facility} active_patients_counts: {count}. Did you mean 'Awaiting Nursing Home (W2)'?")
                else:
                    logger.warning(f"Invalid or terminal state {state} in {facility} active_patients_counts: {count}")
                continue
            if not isinstance(count, int) or count < 0:
                logger.warning(f"Invalid count for {state} in {facility}: {count}. Skipping.")
                continue
            for _ in range(count):
                global_client_id_counter_ref[0] += 1
                client_id = global_client_id_counter_ref[0]
                client = Client(env, client_id, stats, resources, initial_state=state)
                current_week_clients.append(client)
                env.process(client.run())
        
        # Add new patients
        for _ in range(new_patients): # Fixed count of new patients per week.
            global_client_id_counter_ref[0] += 1
            client_id = global_client_id_counter_ref[0]
            client = Client(env, client_id, stats, resources, initial_state="Home")
            current_week_clients.append(client)
            env.process(client.run())
        
        env.run(until=SIM_TIME_PER_WEEK)
        active_patients_data_out = []
        for client in current_week_clients:
            if client.alive and client.state not in ["Discharge", "Passed Away"]:
                active_patients_data_out.append({'id': client.id, 'state': client.state})
                stats.record_time(client.state, env.now - client.state_entry_time)
        logger.info(f"{facility} Week {week_num}: Active patients at end: {len(active_patients_data_out)}, Total processed: {len(current_week_clients)}")
        return active_patients_data_out, global_client_id_counter_ref, stats.get_metrics(week_start_date)
    except Exception as e:
        logger.error(f"Error in simulation for {facility} week {week_num}: {str(e)}")
        raise

    # Steps:
# Validates capacities against FACILITIES.
# Initializes SimPy environment and resources.
# Creates Stats with active_patients_counts.
# Initializes clients from active_patients_counts and new_patients.
# Runs simulation for 168 hours.
#Collects active patients (active_patients_data_out) and metrics.
    # Validation:
# Skips invalid states (e.g., Awaiting Nursing Home → suggests W2).
# Ensures counts are non-negative integers.

# Cloud Interaction
# Fetches active patients counts from Firestore for the given week.
def get_active_patients_counts(facility, week_date):
    try:
        week_ref = db.collection('real-time data').document(facility).collection('weeks').document(f'week_{week_date}')
        doc = week_ref.get()
        if doc.exists:
            active_patients = doc.to_dict().get('active_patients', {})
            logger.info(f"Fetched active patients for {facility} week {week_date}: {active_patients}")
            return active_patients
        else:
            logger.warning(f"No real-time data for {facility} week {week_date}. Using empty active patients.")
            return {}
    except Exception as e:
        logger.error(f"Error fetching active patients for {facility} week {week_date}: {str(e)}")
        return {}
        
def get_capacities(facility):
    try:
        facility_ref = db.collection('prediction').document(facility)
        capacities = facility_ref.get().to_dict().get('capacities', FACILITIES[facility])
        if VERBOSE_LOGGING:
            logger.debug(f"Fetched capacities for {facility}: {capacities}")
        return capacities
    except Exception as e:
        logger.error(f"Error fetching capacities for {facility}: {str(e)}")
        return FACILITIES[facility]

def run_simulation_with_cloud(week_to_run=None):
    facilities = ["Arnhem", "Nijmegen"]
    base_date = datetime(2025, 5, 1)
    
    if week_to_run is not None:
        weeks = [week_to_run]
    else:
        weeks = range(1, TOTAL_SIMULATION_WEEKS + 1)
    
    for week in weeks:
        week_start_date = base_date + timedelta(weeks=week-1)
        week_start_date_str = week_start_date.strftime('%Y-%m-%d')
        next_week_date = week_start_date + timedelta(weeks=1)
        next_week_date_str = next_week_date.strftime('%Y-%m-%d')
        
        for facility in facilities:
            active_patients_counts = get_active_patients_counts(facility, week_start_date_str)
            capacities = get_capacities(facility)
            if not capacities:
                logger.error(f"No capacities found for {facility}. Skipping simulation.")
                continue
            new_patients = NUM_NEW_PATIENTS_PER_WEEK[facility]
            global_client_id_counter = [0]  # Reset counter per week
            
            try:
                np.random.seed(week * facilities.index(facility) * 42 + np.random.randint(1000))
                active_patients_data_out, global_client_id_counter, metrics = run_one_week_simulation(
                    week_num=week,
                    active_patients_counts=active_patients_counts,
                    global_client_id_counter_ref=global_client_id_counter,
                    facility=facility,
                    week_start_date=next_week_date_str,
                    capacities=capacities,
                    new_patients=new_patients
                )
                
                facility_ref = db.collection('prediction').document(facility)
                week_ref = facility_ref.collection('weeks').document(f'week_{next_week_date_str}')
                try:
                    week_ref.set({
                        'date': next_week_date_str,
                        'active_patients_data': active_patients_data_out,
                        'metrics': metrics,
                        'timestamp': firestore.SERVER_TIMESTAMP
                    })
                    logger.info(f"Updated {facility} for week {next_week_date_str} with {new_patients} new patients")
                except Exception as e:
                    logger.error(f"Failed to update Firestore for {facility} week {next_week_date_str}: {str(e)}")
            except Exception as e:
                logger.error(f"Simulation failed for {facility} week {next_week_date_str}: {str(e)}")

if __name__ == "__main__":
    run_simulation_with_cloud(week_to_run=1) # Runs simulation for week 1. If future weeks are needed, change week_to_run to a specific number (starting from 2025-05-01).
    logger.info("Simulation complete with cloud integration")

# %% [markdown]
# ### BACKUP: LOGIC OF SIMULATION MODEL
#
# This is for readers to read the output of the script below and understand how a patient go within the simulation model. This script solely serves the logic of the simulation model based on the diagram. This script is not complete, please do not use this one, use the script above íntead

# %%
import simpy
import random
import statistics
from collections import defaultdict

# Parameters
SIM_TIME = 1000
NUM_CLIENTS = 100
W1_MEAN = 24
W2_MEAN = 48
PASS_AWAY_PROB = 0.05
TRANSFER_PROB = 0.2
EMERGENCY_PROB = 0.4
NURSING_HOME_STAY_MIN_HOURS = 7 * 24
NURSING_HOME_STAY_MAX_HOURS = 30 * 24

CAPACITY = {
    "General Practitioner": 10,
    "Geriatric Rehabilitation": 10,
    "Short-Term Residential Care": 10,
    "Crisis Admission": 10,
    "Clinical Ward": 10,
    "Acute Admission Unit": 10,
    "Emergency Department": 15,
    "Nursing Home": 20
}

class Stats:
    def __init__(self, env, resources):
        self.env = env
        self.resources = resources
        self.capacity_usage = defaultdict(list)
        self.state_visits = defaultdict(int)
        self.state_times = defaultdict(list)
        self.final_states = defaultdict(int)
        self.pass_away_count = 0
        self.transitions = defaultdict(lambda: defaultdict(int))
        self.env.process(self.monitor_capacity())

    def record_visit(self, state):
        self.state_visits[state] += 1

    def record_time(self, state, duration):
        if duration > 0.001:
            self.state_times[state].append(duration)

    def record_final_state(self, state):
        self.final_states[state] += 1

    def record_pass_away(self):
        self.pass_away_count += 1

    def record_transition(self, from_state, to_state):
        self.transitions[from_state][to_state] += 1

    def monitor_capacity(self):
        while True:
            for state_name, resource_obj in self.resources.items():
                if state_name in CAPACITY:
                    self.capacity_usage[state_name].append(len(resource_obj.users))
            yield self.env.timeout(1)

    def print_summary(self):
        print("\n=== Simulation Statistics Summary ===")
        print("\nNumber of visits to each state:")
        for state, count in self.state_visits.items():
            print(f"{state}: {count} visits")

        print("\nAverage time spent in each state (for clients who completed their stay there):")
        for state, times in sorted(self.state_times.items()):
            if times:
                avg_time = statistics.mean(times)
                print(f"{state}: {avg_time:.2f} hours (based on {len(times)} entries)")
            else:
                print(f"{state}: No time recorded or no clients completed stay")

        print("\nAverage capacity usage (occupancy) per state:")
        for state, usage_data in sorted(self.capacity_usage.items()):
            if state in CAPACITY:
                if usage_data:
                    avg_usage = statistics.mean(usage_data)
                    max_usage = max(usage_data)
                    print(f"{state}: Avg {avg_usage:.2f} clients (Max: {max_usage}, Capacity: {CAPACITY[state]})")
                else:
                    print(f"{state}: No usage recorded (Capacity: {CAPACITY[state]})")

        print("\nTransition counts between states:")
        for from_state, to_states_counts in sorted(self.transitions.items()):
            for to_state, count in sorted(to_states_counts.items()):
                print(f"{from_state} -> {to_state}: {count} transitions")

        print("\nFinal states of clients at SIM_TIME or upon exit:")
        for state, count in sorted(self.final_states.items()):
            print(f"{state}: {count} clients")

        print(f"\nTotal clients who passed away: {self.pass_away_count}")
        if NUM_CLIENTS > 0:
            print(f"Percentage of clients who passed away: {(self.pass_away_count / NUM_CLIENTS * 100):.2f}%")
        else:
            print("Percentage of clients who passed away: N/A (0 clients simulated)")

class Client:
    def __init__(self, env, id, stats, resources):
        self.env = env
        self.id = id
        self.state = "Home"
        self.alive = True
        self.stats = stats
        self.state_entry_time = env.now
        self.resources = resources
        print(f"Client {self.id} starts at Home at time {self.env.now:.2f}") # This print should appear
        self.stats.record_visit(self.state)

    def run(self):
        while self.alive and self.state not in ["Discharge", "Passed Away"]:
            if self.env.now >= SIM_TIME:
                # print(f"Client {self.id} run ending due to SIM_TIME reached in state {self.state}")
                break

            current_state_processed_in_loop = False
            if self.state == "Home":
                yield self.env.process(self.at_home())
                current_state_processed_in_loop = True
            elif self.state == "General Practitioner":
                with self.resources["General Practitioner"].request() as req:
                    yield req
                    yield self.env.process(self.at_gp())
                current_state_processed_in_loop = True
            elif self.state in ["Geriatric Rehabilitation", "Short-Term Residential Care", "Crisis Admission"]:
                with self.resources[self.state].request() as req:
                    yield req
                    yield self.env.process(self.in_short_term_care())
                current_state_processed_in_loop = True
            elif self.state == "Awaiting Nursing Home (W2)":
                yield self.env.process(self.await_nursing_home_w2())
                current_state_processed_in_loop = True
            elif self.state == "Clinical Ward":
                with self.resources["Clinical Ward"].request() as req:
                    yield req
                    yield self.env.process(self.in_clinical_ward())
                current_state_processed_in_loop = True
            elif self.state == "Acute Admission Unit":
                with self.resources["Acute Admission Unit"].request() as req:
                    yield req
                    yield self.env.process(self.in_acute_admission())
                current_state_processed_in_loop = True
            elif self.state == "Emergency Department":
                with self.resources["Emergency Department"].request() as req:
                    yield req
                    yield self.env.process(self.in_emergency_dept())
                current_state_processed_in_loop = True
            elif self.state == "Nursing Home":
                with self.resources["Nursing Home"].request() as req:
                    yield req
                    yield self.env.process(self.in_nursing_home())
                current_state_processed_in_loop = True
            
            if not current_state_processed_in_loop and self.alive and self.state not in ["Discharge", "Passed Away"]:
                print(f"CRITICAL ERROR: Client {self.id} in unhandled state '{self.state}' at {self.env.now:.2f}. Stopping client.")
                self.alive = False # Prevent infinite loop for this client
                break


    def update_state(self, new_state):
        if not self.alive and self.state == "Passed Away" and new_state == "Passed Away": # Already processed
             return
        if not self.alive and new_state != "Passed Away":
            print(f"Warning: Client {self.id} is not alive (state: {self.state}) but tried to move to {new_state}")
            return

        duration = self.env.now - self.state_entry_time
        self.stats.record_time(self.state, duration)
        self.stats.record_transition(self.state, new_state)
        
        old_state = self.state
        self.state = new_state
        self.state_entry_time = self.env.now
        
        if self.state == "Passed Away":
            if self.alive: # Ensure it's only set once
                self.alive = False
        else:
            self.stats.record_visit(self.state)

        print(f"Client {self.id} moved from {old_state} to {self.state} at time {self.env.now:.2f} (Duration in {old_state}: {duration:.2f})")

    def _check_pass_away(self, probability, context_state):
        if self.alive and random.random() < probability:
            print(f"Client {self.id} passed away during {context_state} at time {self.env.now:.2f}")
            self.stats.record_pass_away()
            self.update_state("Passed Away")
            return True
        return False

    def at_home(self):
        if not self.alive: return
        if random.random() < EMERGENCY_PROB:
            self.update_state("Emergency Department")
        else:
            w1_wait_time = random.expovariate(1.0 / W1_MEAN)
            print(f"Client {self.id} entering W1 wait (for GP) for {w1_wait_time:.2f}h at {self.env.now:.2f}")
            yield self.env.timeout(w1_wait_time) # Wait for the W1 duration
            if not self.alive: return # Check if passed away by other means (if model gets complex)

            # Check for passing away ONLY at W1, after the wait
            if self._check_pass_away(PASS_AWAY_PROB, "W1 (waiting for GP)"):
                return 
            if not self.alive: return # Redundant if _check_pass_away is the only way to become not alive here

            print(f"Client {self.id} finished W1 wait, attempting to see GP at {self.env.now:.2f}")
            self.update_state("General Practitioner")

    def at_gp(self):
        if not self.alive: return
        gp_consult_time = random.uniform(0.25, 1)
        yield self.env.timeout(gp_consult_time)
        if not self.alive: return

        rand_stc = random.random()
        next_stc_type = ""
        if rand_stc < 0.3: next_stc_type = "Geriatric Rehabilitation"
        elif rand_stc < 0.6: next_stc_type = "Short-Term Residential Care"
        else: next_stc_type = "Crisis Admission"
        
        stc_admission_wait = random.uniform(0, 48)
        print(f"Client {self.id} from GP referred to {next_stc_type}, admission wait {stc_admission_wait:.2f}h at {self.env.now:.2f}")
        yield self.env.timeout(stc_admission_wait)
        if not self.alive: return
        self.update_state(next_stc_type)

    def in_short_term_care(self):
        if not self.alive: return
        current_stc_type = self.state
        stay_time = random.uniform(24, 72)
        yield self.env.timeout(stay_time)
        if not self.alive: return

        if random.random() < TRANSFER_PROB:
            options = ["Geriatric Rehabilitation", "Short-Term Residential Care", "Crisis Admission"]
            if current_stc_type in options: options.remove(current_stc_type) # Ensure it's removed
            if not options: # Should not happen if there are always other STC types
                 print(f"Warning: Client {self.id} in STC {current_stc_type}, no other STC options to transfer.")
            else:
                new_stc_type = random.choice(options)
                transfer_delay = random.uniform(6, 12)
                print(f"Client {self.id} transferring from {current_stc_type} to {new_stc_type} (delay {transfer_delay:.2f}h) at {self.env.now:.2f}")
                yield self.env.timeout(transfer_delay)
                if not self.alive: return
                self.update_state(new_stc_type)
                return 

        rand_next = random.random()
        next_state_after_stc = ""
        if rand_next < 0.4: next_state_after_stc = "Clinical Ward"
        elif rand_next < 0.7: next_state_after_stc = "Acute Admission Unit"
        else: next_state_after_stc = "Emergency Department"
        self.update_state(next_state_after_stc)

    def _handle_post_acute_care_transition(self): # This is a helper, not a SimPy process method
        if not self.alive: return
        self.update_state("Awaiting Nursing Home (W2)")

    def in_clinical_ward(self):
        if not self.alive: return
        stay_time = random.uniform(48, 120)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        self._handle_post_acute_care_transition()

    def in_acute_admission(self):
        if not self.alive: return
        stay_time = random.uniform(24, 72)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        self._handle_post_acute_care_transition()

    def in_emergency_dept(self):
        if not self.alive: return
        stay_time = random.uniform(6, 24)
        yield self.env.timeout(stay_time)
        if not self.alive: return
        self._handle_post_acute_care_transition()

    def await_nursing_home_w2(self):
        if not self.alive: return
        w2_wait_time = random.expovariate(1.0 / W2_MEAN)
        print(f"Client {self.id} in W2 (awaiting Nursing Home), wait: {w2_wait_time:.2f}h at {self.env.now:.2f}")
        yield self.env.timeout(w2_wait_time)
        if not self.alive: return
        self.update_state("Nursing Home")

    def in_nursing_home(self):
        if not self.alive: return
        stay_duration = random.uniform(NURSING_HOME_STAY_MIN_HOURS, NURSING_HOME_STAY_MAX_HOURS)
        print(f"Client {self.id} in Nursing Home, planned stay: {stay_duration:.2f}h at {self.env.now:.2f}")
        yield self.env.timeout(stay_duration)
        if not self.alive: return
        
        if random.random() < 0.5:
            print(f"Client {self.id} to be discharged (regular trajectory) from Nursing Home at {self.env.now:.2f}")
        else:
            print(f"Client {self.id} to be discharged (priority trajectory) from Nursing Home at {self.env.now:.2f}")
        self.update_state("Discharge")

def run_simulation():
    print("--- Initializing SimPy Environment ---") # Added print
    env = simpy.Environment()
    resources = {state: simpy.Resource(env, capacity=cap) for state, cap in CAPACITY.items()}
    stats = Stats(env, resources)

    clients = []
    print(f"--- Creating {NUM_CLIENTS} clients ---") # Added print
    for i in range(NUM_CLIENTS):
        client = Client(env, i, stats, resources)
        clients.append(client)
        env.process(client.run())
        # Removed conditional yield here to ensure run_simulation is a regular function

    print(f"--- Client creation complete. Starting simulation run until SIM_TIME: {SIM_TIME} ---") # Added print
    env.run(until=SIM_TIME)

    print(f"\n--- Simulation ended at time {env.now:.2f} ---")
    active_clients = 0
    for client in clients:
        if client.alive and client.state not in ["Discharge", "Passed Away"]:
            active_clients +=1
            stats.record_time(client.state, env.now - client.state_entry_time)
            stats.record_final_state(client.state)
        else: 
            stats.record_final_state(client.state) # Record final state for discharged/passed away too
    if NUM_CLIENTS > 0 : # Avoid printing if no clients were made (e.g. NUM_CLIENTS = 0)
        print(f"{active_clients} out of {NUM_CLIENTS} clients were still active (not Discharged or Passed Away) at SIM_TIME.")
    
    stats.print_summary()

if __name__ == "__main__":
    random.seed(42)
    run_simulation() # Calling run_simulation as a regular function now
# Out:
# --- Initializing SimPy Environment ---
# --- Creating 100 clients ---
# Client 0 starts at Home at time 0.00
# Client 1 starts at Home at time 0.00
# Client 2 starts at Home at time 0.00
# Client 3 starts at Home at time 0.00
# Client 4 starts at Home at time 0.00
# Client 5 starts at Home at time 0.00
# Client 6 starts at Home at time 0.00
# Client 7 starts at Home at time 0.00
# Client 8 starts at Home at time 0.00
# Client 9 starts at Home at time 0.00
# Client 10 starts at Home at time 0.00
# Client 11 starts at Home at time 0.00
# Client 12 starts at Home at time 0.00
# Client 13 starts at Home at time 0.00
# Client 14 starts at Home at time 0.00
# Client 15 starts at Home at time 0.00
# Client 16 starts at Home at time 0.00
# Client 17 starts at Home at time 0.00
# Client 18 starts at Home at time 0.00
# Client 19 starts at Home at time 0.00
# Client 20 starts at Home at time 0.00
# Client 21 starts at Home at time 0.00
# Client 22 starts at Home at time 0.00
# Client 23 starts at Home at time 0.00
# Client 24 starts at Home at time 0.00
# Client 25 starts at Home at time 0.00
# Client 26 starts at Home at time 0.00
# Client 27 starts at Home at time 0.00
# Client 28 starts at Home at time 0.00
# Client 29 starts at Home at time 0.00
# Client 30 starts at Home at time 0.00
# Client 31 starts at Home at time 0.00
# Client 32 starts at Home at time 0.00
# Client 33 starts at Home at time 0.00
# Client 34 starts at Home at time 0.00
# Client 35 starts at Home at time 0.00
# Client 36 starts at Home at time 0.00
# Client 37 starts at Home at time 0.00
# Client 38 starts at Home at time 0.00
# Client 39 starts at Home at time 0.00
# Client 40 starts at Home at time 0.00
# Client 41 starts at Home at time 0.00
# Client 42 starts at Home at time 0.00
# Client 43 starts at Home at time 0.00
# Client 44 starts at Home at time 0.00
# Client 45 starts at Home at time 0.00
# Client 46 starts at Home at time 0.00
# Client 47 starts at Home at time 0.00
# Client 48 starts at Home at time 0.00
# Client 49 starts at Home at time 0.00
# Client 50 starts at Home at time 0.00
# Client 51 starts at Home at time 0.00
# Client 52 starts at Home at time 0.00
# Client 53 starts at Home at time 0.00
# Client 54 starts at Home at time 0.00
# Client 55 starts at Home at time 0.00
# Client 56 starts at Home at time 0.00
# Client 57 starts at Home at time 0.00
# Client 58 starts at Home at time 0.00
# Client 59 starts at Home at time 0.00
# Client 60 starts at Home at time 0.00
# Client 61 starts at Home at time 0.00
# Client 62 starts at Home at time 0.00
# Client 63 starts at Home at time 0.00
# Client 64 starts at Home at time 0.00
# Client 65 starts at Home at time 0.00
# Client 66 starts at Home at time 0.00
# Client 67 starts at Home at time 0.00
# Client 68 starts at Home at time 0.00
# Client 69 starts at Home at time 0.00
# Client 70 starts at Home at time 0.00
# Client 71 starts at Home at time 0.00
# Client 72 starts at Home at time 0.00
# Client 73 starts at Home at time 0.00
# Client 74 starts at Home at time 0.00
# Client 75 starts at Home at time 0.00
# Client 76 starts at Home at time 0.00
# Client 77 starts at Home at time 0.00
# Client 78 starts at Home at time 0.00
# Client 79 starts at Home at time 0.00
# Client 80 starts at Home at time 0.00
# Client 81 starts at Home at time 0.00
# Client 82 starts at Home at time 0.00
# Client 83 starts at Home at time 0.00
# Client 84 starts at Home at time 0.00
# Client 85 starts at Home at time 0.00
# Client 86 starts at Home at time 0.00
# Client 87 starts at Home at time 0.00
# Client 88 starts at Home at time 0.00
# Client 89 starts at Home at time 0.00
# Client 90 starts at Home at time 0.00
# Client 91 starts at Home at time 0.00
# Client 92 starts at Home at time 0.00
# Client 93 starts at Home at time 0.00
# Client 94 starts at Home at time 0.00
# Client 95 starts at Home at time 0.00
# Client 96 starts at Home at time 0.00
# Client 97 starts at Home at time 0.00
# Client 98 starts at Home at time 0.00
# Client 99 starts at Home at time 0.00
# --- Client creation complete. Starting simulation run until SIM_TIME: 1000 ---
# Client 0 entering W1 wait (for GP) for 0.61h at 0.00
# Client 1 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 2 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 3 entering W1 wait (for GP) for 27.10h at 0.00
# Client 4 entering W1 wait (for GP) for 2.18h at 0.00
# Client 5 entering W1 wait (for GP) for 0.73h at 0.00
# Client 6 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 7 entering W1 wait (for GP) for 0.65h at 0.00
# Client 8 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 9 entering W1 wait (for GP) for 18.90h at 0.00
# Client 10 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 11 entering W1 wait (for GP) for 39.79h at 0.00
# Client 12 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 13 entering W1 wait (for GP) for 28.75h at 0.00
# Client 14 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 15 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 16 entering W1 wait (for GP) for 9.85h at 0.00
# Client 17 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 18 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 19 entering W1 wait (for GP) for 22.22h at 0.00
# Client 20 entering W1 wait (for GP) for 31.40h at 0.00
# Client 21 entering W1 wait (for GP) for 86.79h at 0.00
# Client 22 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 23 entering W1 wait (for GP) for 42.44h at 0.00
# Client 24 entering W1 wait (for GP) for 47.48h at 0.00
# Client 25 entering W1 wait (for GP) for 29.26h at 0.00
# Client 26 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 27 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 28 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 29 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 30 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 31 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 32 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 33 entering W1 wait (for GP) for 10.89h at 0.00
# Client 34 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 35 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 36 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 37 entering W1 wait (for GP) for 25.06h at 0.00
# Client 38 entering W1 wait (for GP) for 4.50h at 0.00
# Client 39 entering W1 wait (for GP) for 4.28h at 0.00
# Client 40 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 41 entering W1 wait (for GP) for 24.52h at 0.00
# Client 42 entering W1 wait (for GP) for 27.70h at 0.00
# Client 43 entering W1 wait (for GP) for 35.91h at 0.00
# Client 44 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 45 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 46 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 47 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 48 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 49 entering W1 wait (for GP) for 50.17h at 0.00
# Client 50 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 51 entering W1 wait (for GP) for 12.09h at 0.00
# Client 52 entering W1 wait (for GP) for 14.74h at 0.00
# Client 53 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 54 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 55 entering W1 wait (for GP) for 7.32h at 0.00
# Client 56 entering W1 wait (for GP) for 54.75h at 0.00
# Client 57 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 58 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 59 entering W1 wait (for GP) for 17.10h at 0.00
# Client 60 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 61 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 62 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 63 entering W1 wait (for GP) for 37.69h at 0.00
# Client 64 entering W1 wait (for GP) for 1.58h at 0.00
# Client 65 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 66 entering W1 wait (for GP) for 18.08h at 0.00
# Client 67 entering W1 wait (for GP) for 47.32h at 0.00
# Client 68 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 69 entering W1 wait (for GP) for 27.48h at 0.00
# Client 70 entering W1 wait (for GP) for 7.45h at 0.00
# Client 71 entering W1 wait (for GP) for 2.84h at 0.00
# Client 72 entering W1 wait (for GP) for 14.51h at 0.00
# Client 73 entering W1 wait (for GP) for 50.07h at 0.00
# Client 74 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 75 entering W1 wait (for GP) for 4.72h at 0.00
# Client 76 entering W1 wait (for GP) for 49.06h at 0.00
# Client 77 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 78 entering W1 wait (for GP) for 22.54h at 0.00
# Client 79 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 80 entering W1 wait (for GP) for 18.60h at 0.00
# Client 81 entering W1 wait (for GP) for 18.14h at 0.00
# Client 82 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 83 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 84 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 85 entering W1 wait (for GP) for 50.63h at 0.00
# Client 86 entering W1 wait (for GP) for 8.82h at 0.00
# Client 87 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 88 entering W1 wait (for GP) for 70.48h at 0.00
# Client 89 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 90 entering W1 wait (for GP) for 1.72h at 0.00
# Client 91 entering W1 wait (for GP) for 34.84h at 0.00
# Client 92 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 93 entering W1 wait (for GP) for 19.15h at 0.00
# Client 94 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 95 entering W1 wait (for GP) for 13.20h at 0.00
# Client 96 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 97 entering W1 wait (for GP) for 31.42h at 0.00
# Client 98 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 99 moved from Home to Emergency Department at time 0.00 (Duration in Home: 0.00)
# Client 0 finished W1 wait, attempting to see GP at 0.61
# Client 0 moved from Home to General Practitioner at time 0.61 (Duration in Home: 0.61)
# Client 7 finished W1 wait, attempting to see GP at 0.65
# Client 7 moved from Home to General Practitioner at time 0.65 (Duration in Home: 0.65)
# Client 5 finished W1 wait, attempting to see GP at 0.73
# Client 5 moved from Home to General Practitioner at time 0.73 (Duration in Home: 0.73)
# Client 0 from GP referred to Short-Term Residential Care, admission wait 22.69h at 1.04
# Client 7 from GP referred to Crisis Admission, admission wait 38.76h at 1.06
# Client 64 finished W1 wait, attempting to see GP at 1.58
# Client 64 moved from Home to General Practitioner at time 1.58 (Duration in Home: 1.58)
# Client 5 from GP referred to Short-Term Residential Care, admission wait 20.33h at 1.68
# Client 90 finished W1 wait, attempting to see GP at 1.72
# Client 90 moved from Home to General Practitioner at time 1.72 (Duration in Home: 1.72)
# Client 64 from GP referred to Crisis Admission, admission wait 47.24h at 1.90
# Client 4 finished W1 wait, attempting to see GP at 2.18
# Client 4 moved from Home to General Practitioner at time 2.18 (Duration in Home: 2.18)
# Client 90 from GP referred to Short-Term Residential Care, admission wait 41.36h at 2.52
# Client 4 from GP referred to Geriatric Rehabilitation, admission wait 9.13h at 2.73
# Client 71 finished W1 wait, attempting to see GP at 2.84
# Client 71 moved from Home to General Practitioner at time 2.84 (Duration in Home: 2.84)
# Client 71 from GP referred to Geriatric Rehabilitation, admission wait 11.99h at 3.41
# Client 39 finished W1 wait, attempting to see GP at 4.28
# Client 39 moved from Home to General Practitioner at time 4.28 (Duration in Home: 4.28)
# Client 38 finished W1 wait, attempting to see GP at 4.50
# Client 38 moved from Home to General Practitioner at time 4.50 (Duration in Home: 4.50)
# Client 75 finished W1 wait, attempting to see GP at 4.72
# Client 75 moved from Home to General Practitioner at time 4.72 (Duration in Home: 4.72)
# Client 39 from GP referred to Crisis Admission, admission wait 46.51h at 4.86
# Client 38 from GP referred to Crisis Admission, admission wait 40.74h at 5.17
# Client 75 from GP referred to Geriatric Rehabilitation, admission wait 23.31h at 5.72
# Client 22 moved from Emergency Department to Awaiting Nursing Home (W2) at time 7.28 (Duration in Emergency Department: 7.28)
# Client 22 in W2 (awaiting Nursing Home), wait: 11.54h at 7.28
# Client 55 finished W1 wait, attempting to see GP at 7.32
# Client 55 moved from Home to General Practitioner at time 7.32 (Duration in Home: 7.32)
# Client 70 finished W1 wait, attempting to see GP at 7.45
# Client 70 moved from Home to General Practitioner at time 7.45 (Duration in Home: 7.45)
# Client 10 moved from Emergency Department to Awaiting Nursing Home (W2) at time 8.18 (Duration in Emergency Department: 8.18)
# Client 10 in W2 (awaiting Nursing Home), wait: 202.58h at 8.18
# Client 86 finished W1 wait, attempting to see GP at 8.82
# Client 86 moved from Home to General Practitioner at time 8.82 (Duration in Home: 8.82)
# Client 16 finished W1 wait, attempting to see GP at 9.85
# Client 16 moved from Home to General Practitioner at time 9.85 (Duration in Home: 9.85)
# Client 18 moved from Emergency Department to Awaiting Nursing Home (W2) at time 9.96 (Duration in Emergency Department: 9.96)
# Client 18 in W2 (awaiting Nursing Home), wait: 26.40h at 9.96
# Client 12 moved from Emergency Department to Awaiting Nursing Home (W2) at time 10.04 (Duration in Emergency Department: 10.04)
# Client 12 in W2 (awaiting Nursing Home), wait: 258.56h at 10.04
# Client 27 moved from Emergency Department to Awaiting Nursing Home (W2) at time 10.12 (Duration in Emergency Department: 10.12)
# Client 27 in W2 (awaiting Nursing Home), wait: 60.83h at 10.12
# Client 17 moved from Emergency Department to Awaiting Nursing Home (W2) at time 10.14 (Duration in Emergency Department: 10.14)
# Client 17 in W2 (awaiting Nursing Home), wait: 16.90h at 10.14
# Client 33 finished W1 wait, attempting to see GP at 10.89
# Client 33 moved from Home to General Practitioner at time 10.89 (Duration in Home: 10.89)
# Client 4 moved from General Practitioner to Geriatric Rehabilitation at time 11.86 (Duration in General Practitioner: 9.68)
# Client 14 moved from Emergency Department to Awaiting Nursing Home (W2) at time 12.09 (Duration in Emergency Department: 12.09)
# Client 14 in W2 (awaiting Nursing Home), wait: 2.83h at 12.09
# Client 51 finished W1 wait, attempting to see GP at 12.09
# Client 51 moved from Home to General Practitioner at time 12.09 (Duration in Home: 12.09)
# Client 55 from GP referred to Crisis Admission, admission wait 7.56h at 12.68
# Client 95 finished W1 wait, attempting to see GP at 13.20
# Client 95 moved from Home to General Practitioner at time 13.20 (Duration in Home: 13.20)
# Client 6 moved from Emergency Department to Awaiting Nursing Home (W2) at time 13.89 (Duration in Emergency Department: 13.89)
# Client 6 in W2 (awaiting Nursing Home), wait: 4.01h at 13.89
# Client 72 finished W1 wait, attempting to see GP at 14.51
# Client 72 moved from Home to General Practitioner at time 14.51 (Duration in Home: 14.51)
# Client 52 finished W1 wait, attempting to see GP at 14.74
# Client 52 moved from Home to General Practitioner at time 14.74 (Duration in Home: 14.74)
# Client 14 moved from Awaiting Nursing Home (W2) to Nursing Home at time 14.91 (Duration in Awaiting Nursing Home (W2): 2.83)
# Client 14 in Nursing Home, planned stay: 297.83h at 14.91
# Client 8 moved from Emergency Department to Awaiting Nursing Home (W2) at time 15.32 (Duration in Emergency Department: 15.32)
# Client 8 in W2 (awaiting Nursing Home), wait: 6.13h at 15.32
# Client 71 moved from General Practitioner to Geriatric Rehabilitation at time 15.40 (Duration in General Practitioner: 12.56)
# Client 70 from GP referred to Crisis Admission, admission wait 20.12h at 16.09
# Client 15 moved from Emergency Department to Awaiting Nursing Home (W2) at time 16.59 (Duration in Emergency Department: 16.59)
# Client 15 in W2 (awaiting Nursing Home), wait: 42.06h at 16.59
# Client 59 finished W1 wait, attempting to see GP at 17.10
# Client 59 moved from Home to General Practitioner at time 17.10 (Duration in Home: 17.10)
# Client 26 moved from Emergency Department to Awaiting Nursing Home (W2) at time 17.36 (Duration in Emergency Department: 17.36)
# Client 26 in W2 (awaiting Nursing Home), wait: 10.97h at 17.36
# Client 2 moved from Emergency Department to Awaiting Nursing Home (W2) at time 17.70 (Duration in Emergency Department: 17.70)
# Client 2 in W2 (awaiting Nursing Home), wait: 13.09h at 17.70
# Client 6 moved from Awaiting Nursing Home (W2) to Nursing Home at time 17.89 (Duration in Awaiting Nursing Home (W2): 4.01)
# Client 6 in Nursing Home, planned stay: 538.77h at 17.89
# Client 66 finished W1 wait, attempting to see GP at 18.08
# Client 66 moved from Home to General Practitioner at time 18.08 (Duration in Home: 18.08)
# Client 81 finished W1 wait, attempting to see GP at 18.14
# Client 81 moved from Home to General Practitioner at time 18.14 (Duration in Home: 18.14)
# Client 80 finished W1 wait, attempting to see GP at 18.60
# Client 80 moved from Home to General Practitioner at time 18.60 (Duration in Home: 18.60)
# Client 22 moved from Awaiting Nursing Home (W2) to Nursing Home at time 18.82 (Duration in Awaiting Nursing Home (W2): 11.54)
# Client 22 in Nursing Home, planned stay: 208.04h at 18.82
# Client 9 finished W1 wait, attempting to see GP at 18.90
# Client 9 moved from Home to General Practitioner at time 18.90 (Duration in Home: 18.90)
# Client 35 moved from Emergency Department to Awaiting Nursing Home (W2) at time 18.91 (Duration in Emergency Department: 18.91)
# Client 35 in W2 (awaiting Nursing Home), wait: 310.67h at 18.91
# Client 31 moved from Emergency Department to Awaiting Nursing Home (W2) at time 18.95 (Duration in Emergency Department: 18.95)
# Client 31 in W2 (awaiting Nursing Home), wait: 3.65h at 18.95
# Client 93 finished W1 wait, attempting to see GP at 19.15
# Client 93 moved from Home to General Practitioner at time 19.15 (Duration in Home: 19.15)
# Client 55 moved from General Practitioner to Crisis Admission at time 20.23 (Duration in General Practitioner: 12.92)
# Client 30 moved from Emergency Department to Awaiting Nursing Home (W2) at time 20.50 (Duration in Emergency Department: 20.50)
# Client 30 in W2 (awaiting Nursing Home), wait: 101.48h at 20.50
# Client 86 from GP referred to Geriatric Rehabilitation, admission wait 40.02h at 21.14
# Client 8 moved from Awaiting Nursing Home (W2) to Nursing Home at time 21.45 (Duration in Awaiting Nursing Home (W2): 6.13)
# Client 8 in Nursing Home, planned stay: 556.35h at 21.45
# Client 29 moved from Emergency Department to Awaiting Nursing Home (W2) at time 21.47 (Duration in Emergency Department: 21.47)
# Client 29 in W2 (awaiting Nursing Home), wait: 45.40h at 21.47
# Client 5 moved from General Practitioner to Short-Term Residential Care at time 22.01 (Duration in General Practitioner: 21.28)
# Client 19 finished W1 wait, attempting to see GP at 22.22
# Client 19 moved from Home to General Practitioner at time 22.22 (Duration in Home: 22.22)
# Client 16 from GP referred to Geriatric Rehabilitation, admission wait 31.84h at 22.27
# Client 28 moved from Emergency Department to Awaiting Nursing Home (W2) at time 22.30 (Duration in Emergency Department: 22.30)
# Client 28 in W2 (awaiting Nursing Home), wait: 134.20h at 22.30
# Client 78 finished W1 wait, attempting to see GP at 22.54
# Client 78 moved from Home to General Practitioner at time 22.54 (Duration in Home: 22.54)
# Client 31 moved from Awaiting Nursing Home (W2) to Nursing Home at time 22.60 (Duration in Awaiting Nursing Home (W2): 3.65)
# Client 31 in Nursing Home, planned stay: 227.08h at 22.60
# Client 44 moved from Emergency Department to Awaiting Nursing Home (W2) at time 23.23 (Duration in Emergency Department: 23.23)
# Client 44 in W2 (awaiting Nursing Home), wait: 38.67h at 23.23
# Client 0 moved from General Practitioner to Short-Term Residential Care at time 23.72 (Duration in General Practitioner: 23.12)
# Client 1 moved from Emergency Department to Awaiting Nursing Home (W2) at time 23.91 (Duration in Emergency Department: 23.91)
# Client 1 in W2 (awaiting Nursing Home), wait: 10.93h at 23.91
# Client 33 from GP referred to Geriatric Rehabilitation, admission wait 23.45h at 24.51
# Client 41 finished W1 wait, attempting to see GP at 24.52
# Client 41 moved from Home to General Practitioner at time 24.52 (Duration in Home: 24.52)
# Client 37 finished W1 wait, attempting to see GP at 25.06
# Client 37 moved from Home to General Practitioner at time 25.06 (Duration in Home: 25.06)
# Client 34 moved from Emergency Department to Awaiting Nursing Home (W2) at time 26.05 (Duration in Emergency Department: 26.05)
# Client 34 in W2 (awaiting Nursing Home), wait: 4.65h at 26.05
# Client 17 moved from Awaiting Nursing Home (W2) to Nursing Home at time 27.04 (Duration in Awaiting Nursing Home (W2): 16.90)
# Client 17 in Nursing Home, planned stay: 320.73h at 27.04
# Client 3 passed away during W1 (waiting for GP) at time 27.10
# Client 3 moved from Home to Passed Away at time 27.10 (Duration in Home: 27.10)
# Client 69 finished W1 wait, attempting to see GP at 27.48
# Client 69 moved from Home to General Practitioner at time 27.48 (Duration in Home: 27.48)
# Client 42 finished W1 wait, attempting to see GP at 27.70
# Client 42 moved from Home to General Practitioner at time 27.70 (Duration in Home: 27.70)
# Client 26 moved from Awaiting Nursing Home (W2) to Nursing Home at time 28.33 (Duration in Awaiting Nursing Home (W2): 10.97)
# Client 26 in Nursing Home, planned stay: 312.60h at 28.33
# Client 40 moved from Emergency Department to Awaiting Nursing Home (W2) at time 28.60 (Duration in Emergency Department: 28.60)
# Client 40 in W2 (awaiting Nursing Home), wait: 64.89h at 28.60
# Client 13 finished W1 wait, attempting to see GP at 28.75
# Client 13 moved from Home to General Practitioner at time 28.75 (Duration in Home: 28.75)
# Client 53 moved from Emergency Department to Awaiting Nursing Home (W2) at time 28.79 (Duration in Emergency Department: 28.79)
# Client 53 in W2 (awaiting Nursing Home), wait: 0.47h at 28.79
# Client 75 moved from General Practitioner to Geriatric Rehabilitation at time 29.03 (Duration in General Practitioner: 24.31)
# Client 53 moved from Awaiting Nursing Home (W2) to Nursing Home at time 29.25 (Duration in Awaiting Nursing Home (W2): 0.47)
# Client 53 in Nursing Home, planned stay: 469.17h at 29.25
# Client 25 finished W1 wait, attempting to see GP at 29.26
# Client 25 moved from Home to General Practitioner at time 29.26 (Duration in Home: 29.26)
# Client 51 from GP referred to Short-Term Residential Care, admission wait 7.11h at 29.96
# Client 34 moved from Awaiting Nursing Home (W2) to Nursing Home at time 30.70 (Duration in Awaiting Nursing Home (W2): 4.65)
# Client 34 in Nursing Home, planned stay: 238.35h at 30.70
# Client 58 moved from Emergency Department to Awaiting Nursing Home (W2) at time 30.71 (Duration in Emergency Department: 30.71)
# Client 58 in W2 (awaiting Nursing Home), wait: 17.69h at 30.71
# Client 2 moved from Awaiting Nursing Home (W2) to Nursing Home at time 30.79 (Duration in Awaiting Nursing Home (W2): 13.09)
# Client 2 in Nursing Home, planned stay: 607.46h at 30.79
# Client 48 moved from Emergency Department to Awaiting Nursing Home (W2) at time 30.82 (Duration in Emergency Department: 30.82)
# Client 48 in W2 (awaiting Nursing Home), wait: 94.61h at 30.82
# Client 20 finished W1 wait, attempting to see GP at 31.40
# Client 20 moved from Home to General Practitioner at time 31.40 (Duration in Home: 31.40)
# Client 97 finished W1 wait, attempting to see GP at 31.42
# Client 97 moved from Home to General Practitioner at time 31.42 (Duration in Home: 31.42)
# Client 46 moved from Emergency Department to Awaiting Nursing Home (W2) at time 32.00 (Duration in Emergency Department: 32.00)
# Client 46 in W2 (awaiting Nursing Home), wait: 5.21h at 32.00
# Client 54 moved from Emergency Department to Awaiting Nursing Home (W2) at time 33.15 (Duration in Emergency Department: 33.15)
# Client 54 in W2 (awaiting Nursing Home), wait: 103.46h at 33.15
# Client 32 moved from Emergency Department to Awaiting Nursing Home (W2) at time 33.20 (Duration in Emergency Department: 33.20)
# Client 32 in W2 (awaiting Nursing Home), wait: 46.53h at 33.20
# Client 36 moved from Emergency Department to Awaiting Nursing Home (W2) at time 33.58 (Duration in Emergency Department: 33.58)
# Client 36 in W2 (awaiting Nursing Home), wait: 127.56h at 33.58
# Client 60 moved from Emergency Department to Awaiting Nursing Home (W2) at time 34.13 (Duration in Emergency Department: 34.13)
# Client 60 in W2 (awaiting Nursing Home), wait: 179.44h at 34.13
# Client 1 moved from Awaiting Nursing Home (W2) to Nursing Home at time 34.84 (Duration in Awaiting Nursing Home (W2): 10.93)
# Client 1 in Nursing Home, planned stay: 654.54h at 34.84
# Client 91 passed away during W1 (waiting for GP) at time 34.84
# Client 91 moved from Home to Passed Away at time 34.84 (Duration in Home: 34.84)
# Client 43 finished W1 wait, attempting to see GP at 35.91
# Client 43 moved from Home to General Practitioner at time 35.91 (Duration in Home: 35.91)
# Client 68 moved from Emergency Department to Awaiting Nursing Home (W2) at time 36.14 (Duration in Emergency Department: 36.14)
# Client 68 in W2 (awaiting Nursing Home), wait: 19.38h at 36.14
# Client 70 moved from General Practitioner to Crisis Admission at time 36.21 (Duration in General Practitioner: 28.77)
# Client 47 moved from Emergency Department to Awaiting Nursing Home (W2) at time 36.25 (Duration in Emergency Department: 36.25)
# Client 47 in W2 (awaiting Nursing Home), wait: 79.90h at 36.25
# Client 18 moved from Awaiting Nursing Home (W2) to Nursing Home at time 36.36 (Duration in Awaiting Nursing Home (W2): 26.40)
# Client 18 in Nursing Home, planned stay: 602.63h at 36.36
# Client 51 moved from General Practitioner to Short-Term Residential Care at time 37.07 (Duration in General Practitioner: 24.98)
# Client 95 from GP referred to Crisis Admission, admission wait 10.68h at 37.11
# Client 46 moved from Awaiting Nursing Home (W2) to Nursing Home at time 37.21 (Duration in Awaiting Nursing Home (W2): 5.21)
# Client 46 in Nursing Home, planned stay: 618.76h at 37.21
# Client 45 moved from Emergency Department to Awaiting Nursing Home (W2) at time 37.34 (Duration in Emergency Department: 37.34)
# Client 45 in W2 (awaiting Nursing Home), wait: 29.60h at 37.34
# Client 63 finished W1 wait, attempting to see GP at 37.69
# Client 63 moved from Home to General Practitioner at time 37.69 (Duration in Home: 37.69)
# Client 72 from GP referred to Geriatric Rehabilitation, admission wait 1.14h at 37.97
# Client 72 moved from General Practitioner to Geriatric Rehabilitation at time 39.11 (Duration in General Practitioner: 24.60)
# Client 52 from GP referred to Crisis Admission, admission wait 46.41h at 39.61
# Client 62 moved from Emergency Department to Awaiting Nursing Home (W2) at time 39.67 (Duration in Emergency Department: 39.67)
# Client 62 in W2 (awaiting Nursing Home), wait: 15.71h at 39.67
# Client 11 finished W1 wait, attempting to see GP at 39.79
# Client 11 moved from Home to General Practitioner at time 39.79 (Duration in Home: 39.79)
# Client 7 moved from General Practitioner to Crisis Admission at time 39.82 (Duration in General Practitioner: 39.17)
# Client 59 from GP referred to Crisis Admission, admission wait 5.54h at 40.47
# Client 61 moved from Emergency Department to Awaiting Nursing Home (W2) at time 41.33 (Duration in Emergency Department: 41.33)
# Client 61 in W2 (awaiting Nursing Home), wait: 168.96h at 41.33
# Client 83 moved from Emergency Department to Awaiting Nursing Home (W2) at time 41.98 (Duration in Emergency Department: 41.98)
# Client 83 in W2 (awaiting Nursing Home), wait: 157.65h at 41.98
# Client 23 finished W1 wait, attempting to see GP at 42.44
# Client 23 moved from Home to General Practitioner at time 42.44 (Duration in Home: 42.44)
# Client 50 moved from Emergency Department to Awaiting Nursing Home (W2) at time 42.84 (Duration in Emergency Department: 42.84)
# Client 50 in W2 (awaiting Nursing Home), wait: 27.37h at 42.84
# Client 90 moved from General Practitioner to Short-Term Residential Care at time 43.88 (Duration in General Practitioner: 42.16)
# Client 66 from GP referred to Crisis Admission, admission wait 24.55h at 44.36
# Client 65 moved from Emergency Department to Awaiting Nursing Home (W2) at time 44.53 (Duration in Emergency Department: 44.53)
# Client 65 in W2 (awaiting Nursing Home), wait: 23.35h at 44.53
# Client 57 moved from Emergency Department to Awaiting Nursing Home (W2) at time 45.24 (Duration in Emergency Department: 45.24)
# Client 57 in W2 (awaiting Nursing Home), wait: 41.25h at 45.24
# Client 38 moved from General Practitioner to Crisis Admission at time 45.90 (Duration in General Practitioner: 41.40)
# Client 59 moved from General Practitioner to Crisis Admission at time 46.00 (Duration in General Practitioner: 28.91)
# Client 82 moved from Emergency Department to Awaiting Nursing Home (W2) at time 46.46 (Duration in Emergency Department: 46.46)
# Client 82 in W2 (awaiting Nursing Home), wait: 37.11h at 46.46
# Client 81 from GP referred to Crisis Admission, admission wait 35.61h at 46.69
# Client 80 from GP referred to Crisis Admission, admission wait 17.48h at 46.95
# Client 92 moved from Emergency Department to Awaiting Nursing Home (W2) at time 47.05 (Duration in Emergency Department: 47.05)
# Client 92 in W2 (awaiting Nursing Home), wait: 3.48h at 47.05
# Client 67 finished W1 wait, attempting to see GP at 47.32
# Client 67 moved from Home to General Practitioner at time 47.32 (Duration in Home: 47.32)
# Client 24 finished W1 wait, attempting to see GP at 47.48
# Client 24 moved from Home to General Practitioner at time 47.48 (Duration in Home: 47.48)
# Client 95 moved from General Practitioner to Crisis Admission at time 47.79 (Duration in General Practitioner: 34.59)
# Client 33 moved from General Practitioner to Geriatric Rehabilitation at time 47.96 (Duration in General Practitioner: 37.07)
# Client 58 moved from Awaiting Nursing Home (W2) to Nursing Home at time 48.40 (Duration in Awaiting Nursing Home (W2): 17.69)
# Client 58 in Nursing Home, planned stay: 338.73h at 48.40
# Client 93 from GP referred to Short-Term Residential Care, admission wait 19.32h at 48.44
# Client 9 from GP referred to Geriatric Rehabilitation, admission wait 6.11h at 48.68
# Client 94 moved from Emergency Department to Awaiting Nursing Home (W2) at time 48.83 (Duration in Emergency Department: 48.83)
# Client 94 in W2 (awaiting Nursing Home), wait: 26.18h at 48.83
# Client 76 finished W1 wait, attempting to see GP at 49.06
# Client 76 moved from Home to General Practitioner at time 49.06 (Duration in Home: 49.06)
# Client 64 moved from General Practitioner to Crisis Admission at time 49.14 (Duration in General Practitioner: 47.56)
# Client 19 from GP referred to Crisis Admission, admission wait 14.45h at 50.06
# Client 73 finished W1 wait, attempting to see GP at 50.07
# Client 73 moved from Home to General Practitioner at time 50.07 (Duration in Home: 50.07)
# Client 49 passed away during W1 (waiting for GP) at time 50.17
# Client 49 moved from Home to Passed Away at time 50.17 (Duration in Home: 50.17)
# Client 92 moved from Awaiting Nursing Home (W2) to Nursing Home at time 50.54 (Duration in Awaiting Nursing Home (W2): 3.48)
# Client 92 in Nursing Home, planned stay: 326.38h at 50.54
# Client 98 moved from Emergency Department to Awaiting Nursing Home (W2) at time 50.54 (Duration in Emergency Department: 50.54)
# Client 98 in W2 (awaiting Nursing Home), wait: 26.97h at 50.54
# Client 85 finished W1 wait, attempting to see GP at 50.63
# Client 85 moved from Home to General Practitioner at time 50.63 (Duration in Home: 50.63)
# Client 71 moved from Geriatric Rehabilitation to Acute Admission Unit at time 51.21 (Duration in Geriatric Rehabilitation: 35.82)
# Client 39 moved from General Practitioner to Crisis Admission at time 51.38 (Duration in General Practitioner: 47.09)
# Client 78 from GP referred to Crisis Admission, admission wait 38.21h at 51.98
# Client 79 moved from Emergency Department to Awaiting Nursing Home (W2) at time 52.04 (Duration in Emergency Department: 52.04)
# Client 79 in W2 (awaiting Nursing Home), wait: 8.93h at 52.04
# Client 99 moved from Emergency Department to Awaiting Nursing Home (W2) at time 52.76 (Duration in Emergency Department: 52.76)
# Client 99 in W2 (awaiting Nursing Home), wait: 4.25h at 52.76
# Client 74 moved from Emergency Department to Awaiting Nursing Home (W2) at time 52.90 (Duration in Emergency Department: 52.90)
# Client 74 in W2 (awaiting Nursing Home), wait: 34.78h at 52.90
# Client 77 moved from Emergency Department to Awaiting Nursing Home (W2) at time 53.00 (Duration in Emergency Department: 53.00)
# Client 77 in W2 (awaiting Nursing Home), wait: 48.11h at 53.00
# Client 16 moved from General Practitioner to Geriatric Rehabilitation at time 54.11 (Duration in General Practitioner: 44.26)
# Client 87 moved from Emergency Department to Awaiting Nursing Home (W2) at time 54.73 (Duration in Emergency Department: 54.73)
# Client 87 in W2 (awaiting Nursing Home), wait: 66.76h at 54.73
# Client 56 finished W1 wait, attempting to see GP at 54.75
# Client 56 moved from Home to General Practitioner at time 54.75 (Duration in Home: 54.75)
# Client 9 moved from General Practitioner to Geriatric Rehabilitation at time 54.79 (Duration in General Practitioner: 35.89)
# Client 41 from GP referred to Geriatric Rehabilitation, admission wait 11.75h at 54.97
# Client 84 moved from Emergency Department to Awaiting Nursing Home (W2) at time 55.14 (Duration in Emergency Department: 55.14)
# Client 84 in W2 (awaiting Nursing Home), wait: 30.94h at 55.14
# Client 37 from GP referred to Crisis Admission, admission wait 3.50h at 55.18
# Client 62 moved from Awaiting Nursing Home (W2) to Nursing Home at time 55.38 (Duration in Awaiting Nursing Home (W2): 15.71)
# Client 62 in Nursing Home, planned stay: 396.77h at 55.38
# Client 68 moved from Awaiting Nursing Home (W2) to Nursing Home at time 55.52 (Duration in Awaiting Nursing Home (W2): 19.38)
# Client 68 in Nursing Home, planned stay: 515.63h at 55.52
# Client 99 moved from Awaiting Nursing Home (W2) to Nursing Home at time 57.01 (Duration in Awaiting Nursing Home (W2): 4.25)
# Client 99 in Nursing Home, planned stay: 275.33h at 57.01
# Client 96 moved from Emergency Department to Awaiting Nursing Home (W2) at time 57.22 (Duration in Emergency Department: 57.22)
# Client 96 in W2 (awaiting Nursing Home), wait: 57.21h at 57.22
# Client 15 moved from Awaiting Nursing Home (W2) to Nursing Home at time 58.65 (Duration in Awaiting Nursing Home (W2): 42.06)
# Client 15 in Nursing Home, planned stay: 440.90h at 58.65
# Client 37 moved from General Practitioner to Crisis Admission at time 58.68 (Duration in General Practitioner: 33.62)
# Client 89 moved from Emergency Department to Awaiting Nursing Home (W2) at time 58.90 (Duration in Emergency Department: 58.90)
# Client 89 in W2 (awaiting Nursing Home), wait: 0.27h at 58.90
# Client 89 moved from Awaiting Nursing Home (W2) to Nursing Home at time 59.16 (Duration in Awaiting Nursing Home (W2): 0.27)
# Client 89 in Nursing Home, planned stay: 582.53h at 59.16
# Client 69 from GP referred to Crisis Admission, admission wait 5.12h at 59.42
# Client 79 moved from Awaiting Nursing Home (W2) to Nursing Home at time 60.97 (Duration in Awaiting Nursing Home (W2): 8.93)
# Client 86 moved from General Practitioner to Geriatric Rehabilitation at time 61.16 (Duration in General Practitioner: 52.34)
# Client 42 from GP referred to Crisis Admission, admission wait 24.86h at 61.54
# Client 4 transferring from Geriatric Rehabilitation to Short-Term Residential Care (delay 11.50h) at 61.89
# Client 44 moved from Awaiting Nursing Home (W2) to Nursing Home at time 61.90 (Duration in Awaiting Nursing Home (W2): 38.67)
# Client 80 moved from General Practitioner to Crisis Admission at time 64.43 (Duration in General Practitioner: 45.83)
# Client 19 moved from General Practitioner to Crisis Admission at time 64.51 (Duration in General Practitioner: 42.29)
# Client 69 moved from General Practitioner to Crisis Admission at time 64.54 (Duration in General Practitioner: 37.06)
# Client 13 from GP referred to Short-Term Residential Care, admission wait 15.23h at 64.78
# Client 25 from GP referred to Crisis Admission, admission wait 21.24h at 65.11
# Client 20 from GP referred to Crisis Admission, admission wait 42.82h at 65.19
# Client 51 moved from Short-Term Residential Care to Emergency Department at time 66.26 (Duration in Short-Term Residential Care: 29.19)
# Client 41 moved from General Practitioner to Geriatric Rehabilitation at time 66.72 (Duration in General Practitioner: 42.20)
# Client 29 moved from Awaiting Nursing Home (W2) to Nursing Home at time 66.88 (Duration in Awaiting Nursing Home (W2): 45.40)
# Client 45 moved from Awaiting Nursing Home (W2) to Nursing Home at time 66.95 (Duration in Awaiting Nursing Home (W2): 29.60)
# Client 97 from GP referred to Short-Term Residential Care, admission wait 36.09h at 67.62
# Client 93 moved from General Practitioner to Short-Term Residential Care at time 67.75 (Duration in General Practitioner: 48.60)
# Client 65 moved from Awaiting Nursing Home (W2) to Nursing Home at time 67.88 (Duration in Awaiting Nursing Home (W2): 23.35)
# Client 43 from GP referred to Crisis Admission, admission wait 23.26h at 68.21
# Client 66 moved from General Practitioner to Crisis Admission at time 68.91 (Duration in General Practitioner: 50.84)
# Client 63 from GP referred to Short-Term Residential Care, admission wait 34.25h at 69.34
# Client 59 moved from Crisis Admission to Clinical Ward at time 70.09 (Duration in Crisis Admission: 24.08)
# Client 50 moved from Awaiting Nursing Home (W2) to Nursing Home at time 70.20 (Duration in Awaiting Nursing Home (W2): 27.37)
# Client 88 finished W1 wait, attempting to see GP at 70.48
# Client 88 moved from Home to General Practitioner at time 70.48 (Duration in Home: 70.48)
# Client 27 moved from Awaiting Nursing Home (W2) to Nursing Home at time 70.95 (Duration in Awaiting Nursing Home (W2): 60.83)
# Client 72 moved from Geriatric Rehabilitation to Clinical Ward at time 72.38 (Duration in Geriatric Rehabilitation: 33.27)
# Client 4 moved from Geriatric Rehabilitation to Short-Term Residential Care at time 73.40 (Duration in Geriatric Rehabilitation: 61.53)
# Client 94 moved from Awaiting Nursing Home (W2) to Nursing Home at time 75.02 (Duration in Awaiting Nursing Home (W2): 26.18)
# Client 0 moved from Short-Term Residential Care to Acute Admission Unit at time 76.76 (Duration in Short-Term Residential Care: 53.03)
# Client 5 moved from Short-Term Residential Care to Clinical Ward at time 77.40 (Duration in Short-Term Residential Care: 55.39)
# Client 98 moved from Awaiting Nursing Home (W2) to Nursing Home at time 77.52 (Duration in Awaiting Nursing Home (W2): 26.97)
# Client 32 moved from Awaiting Nursing Home (W2) to Nursing Home at time 79.72 (Duration in Awaiting Nursing Home (W2): 46.53)
# Client 13 moved from General Practitioner to Short-Term Residential Care at time 80.01 (Duration in General Practitioner: 51.26)
# Client 11 from GP referred to Crisis Admission, admission wait 27.63h at 80.28
# Client 51 moved from Emergency Department to Awaiting Nursing Home (W2) at time 80.29 (Duration in Emergency Department: 14.03)
# Client 51 in W2 (awaiting Nursing Home), wait: 31.11h at 80.29
# Client 38 moved from Crisis Admission to Clinical Ward at time 82.13 (Duration in Crisis Admission: 36.23)
# Client 81 moved from General Practitioner to Crisis Admission at time 82.30 (Duration in General Practitioner: 64.16)
# Client 23 from GP referred to Short-Term Residential Care, admission wait 35.26h at 83.18
# Client 82 moved from Awaiting Nursing Home (W2) to Nursing Home at time 83.58 (Duration in Awaiting Nursing Home (W2): 37.11)
# Client 39 moved from Crisis Admission to Emergency Department at time 85.63 (Duration in Crisis Admission: 34.26)
# Client 52 moved from General Practitioner to Crisis Admission at time 86.02 (Duration in General Practitioner: 71.28)
# Client 84 moved from Awaiting Nursing Home (W2) to Nursing Home at time 86.08 (Duration in Awaiting Nursing Home (W2): 30.94)
# Client 25 moved from General Practitioner to Crisis Admission at time 86.35 (Duration in General Practitioner: 57.09)
# Client 42 moved from General Practitioner to Crisis Admission at time 86.41 (Duration in General Practitioner: 58.71)
# Client 57 moved from Awaiting Nursing Home (W2) to Nursing Home at time 86.50 (Duration in Awaiting Nursing Home (W2): 41.25)
# Client 67 from GP referred to Crisis Admission, admission wait 34.76h at 86.63
# Client 21 finished W1 wait, attempting to see GP at 86.79
# Client 21 moved from Home to General Practitioner at time 86.79 (Duration in Home: 86.79)
# Client 95 moved from Crisis Admission to Emergency Department at time 86.86 (Duration in Crisis Admission: 39.07)
# Client 24 from GP referred to Short-Term Residential Care, admission wait 31.82h at 86.89
# Client 76 from GP referred to Geriatric Rehabilitation, admission wait 20.57h at 87.16
# Client 74 moved from Awaiting Nursing Home (W2) to Nursing Home at time 87.67 (Duration in Awaiting Nursing Home (W2): 34.78)
# Client 55 moved from Crisis Admission to Clinical Ward at time 89.03 (Duration in Crisis Admission: 68.80)
# Client 9 moved from Geriatric Rehabilitation to Clinical Ward at time 89.57 (Duration in Geriatric Rehabilitation: 34.78)
# Client 78 moved from General Practitioner to Crisis Admission at time 90.19 (Duration in General Practitioner: 67.65)
# Client 73 from GP referred to Crisis Admission, admission wait 20.24h at 90.65
# Client 43 moved from General Practitioner to Crisis Admission at time 91.47 (Duration in General Practitioner: 55.56)
# Client 85 from GP referred to Short-Term Residential Care, admission wait 35.95h at 92.35
# Client 40 moved from Awaiting Nursing Home (W2) to Nursing Home at time 93.49 (Duration in Awaiting Nursing Home (W2): 64.89)
# Client 16 transferring from Geriatric Rehabilitation to Crisis Admission (delay 7.35h) at 94.20
# Client 80 transferring from Crisis Admission to Geriatric Rehabilitation (delay 10.53h) at 94.26
# Client 37 moved from Crisis Admission to Clinical Ward at time 94.39 (Duration in Crisis Admission: 35.71)
# Client 75 transferring from Geriatric Rehabilitation to Short-Term Residential Care (delay 9.38h) at 95.42
# Client 71 moved from Acute Admission Unit to Awaiting Nursing Home (W2) at time 96.44 (Duration in Acute Admission Unit: 45.22)
# Client 71 in W2 (awaiting Nursing Home), wait: 11.80h at 96.44
# Client 19 moved from Crisis Admission to Emergency Department at time 97.95 (Duration in Crisis Admission: 33.44)
# Client 41 moved from Geriatric Rehabilitation to Clinical Ward at time 98.36 (Duration in Geriatric Rehabilitation: 31.64)
# Client 70 moved from Crisis Admission to Clinical Ward at time 98.72 (Duration in Crisis Admission: 62.51)
# Client 39 moved from Emergency Department to Awaiting Nursing Home (W2) at time 100.42 (Duration in Emergency Department: 14.79)
# Client 39 in W2 (awaiting Nursing Home), wait: 54.30h at 100.42
# Client 77 moved from Awaiting Nursing Home (W2) to Nursing Home at time 101.11 (Duration in Awaiting Nursing Home (W2): 48.11)
# Client 16 moved from Geriatric Rehabilitation to Crisis Admission at time 101.54 (Duration in Geriatric Rehabilitation: 47.43)
# Client 95 moved from Emergency Department to Awaiting Nursing Home (W2) at time 102.47 (Duration in Emergency Department: 15.61)
# Client 95 in W2 (awaiting Nursing Home), wait: 152.36h at 102.47
# Client 90 moved from Short-Term Residential Care to Emergency Department at time 102.85 (Duration in Short-Term Residential Care: 58.97)
# Client 63 moved from General Practitioner to Short-Term Residential Care at time 103.59 (Duration in General Practitioner: 65.90)
# Client 97 moved from General Practitioner to Short-Term Residential Care at time 103.71 (Duration in General Practitioner: 72.29)
# Client 0 moved from Acute Admission Unit to Awaiting Nursing Home (W2) at time 103.75 (Duration in Acute Admission Unit: 26.99)
# Client 0 in W2 (awaiting Nursing Home), wait: 91.16h at 103.75
# Client 56 from GP referred to Crisis Admission, admission wait 5.81h at 104.31
# Client 88 from GP referred to Crisis Admission, admission wait 37.57h at 104.53
# Client 80 moved from Crisis Admission to Geriatric Rehabilitation at time 104.78 (Duration in Crisis Admission: 40.35)
# Client 75 moved from Geriatric Rehabilitation to Short-Term Residential Care at time 104.81 (Duration in Geriatric Rehabilitation: 75.77)
# Client 86 moved from Geriatric Rehabilitation to Clinical Ward at time 105.57 (Duration in Geriatric Rehabilitation: 44.41)
# Client 64 moved from Crisis Admission to Clinical Ward at time 105.65 (Duration in Crisis Admission: 56.51)
# Client 33 moved from Geriatric Rehabilitation to Emergency Department at time 106.51 (Duration in Geriatric Rehabilitation: 58.55)
# Client 19 moved from Emergency Department to Awaiting Nursing Home (W2) at time 106.97 (Duration in Emergency Department: 9.02)
# Client 19 in W2 (awaiting Nursing Home), wait: 27.45h at 106.97
# Client 76 moved from General Practitioner to Geriatric Rehabilitation at time 107.73 (Duration in General Practitioner: 58.67)
# Client 11 moved from General Practitioner to Crisis Admission at time 107.91 (Duration in General Practitioner: 68.12)
# Client 20 moved from General Practitioner to Crisis Admission at time 108.00 (Duration in General Practitioner: 76.60)
# Client 71 moved from Awaiting Nursing Home (W2) to Nursing Home at time 108.24 (Duration in Awaiting Nursing Home (W2): 11.80)
# Client 21 from GP referred to Geriatric Rehabilitation, admission wait 38.79h at 108.71
# Client 56 moved from General Practitioner to Crisis Admission at time 110.12 (Duration in General Practitioner: 55.38)
# Client 90 moved from Emergency Department to Awaiting Nursing Home (W2) at time 110.22 (Duration in Emergency Department: 7.37)
# Client 90 in W2 (awaiting Nursing Home), wait: 37.08h at 110.22
# Client 73 moved from General Practitioner to Crisis Admission at time 110.88 (Duration in General Practitioner: 60.81)
# Client 7 moved from Crisis Admission to Acute Admission Unit at time 110.91 (Duration in Crisis Admission: 71.10)
# Client 51 moved from Awaiting Nursing Home (W2) to Nursing Home at time 111.40 (Duration in Awaiting Nursing Home (W2): 31.11)
# Client 96 moved from Awaiting Nursing Home (W2) to Nursing Home at time 114.43 (Duration in Awaiting Nursing Home (W2): 57.21)
# Client 47 moved from Awaiting Nursing Home (W2) to Nursing Home at time 116.16 (Duration in Awaiting Nursing Home (W2): 79.90)
# Client 4 moved from Short-Term Residential Care to Emergency Department at time 117.31 (Duration in Short-Term Residential Care: 43.91)
# Client 23 moved from General Practitioner to Short-Term Residential Care at time 118.44 (Duration in General Practitioner: 76.00)
# ...
# Client 95 moved from Awaiting Nursing Home (W2) to Nursing Home at time 254.83 (Duration in Awaiting Nursing Home (W2): 152.36)
# Client 38 moved from Awaiting Nursing Home (W2) to Nursing Home at time 257.16 (Duration in Awaiting Nursing Home (W2): 98.95)
# Client 16 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 258.48 (Duration in Clinical Ward: 82.71)
# Client 16 in W2 (awaiting Nursing Home), wait: 86.77h at 258.48
# Client 43 moved from Awaiting Nursing Home (W2) to Nursing Home at time 266.22 (Duration in Awaiting Nursing Home (W2): 18.68)
# Client 78 moved from Crisis Admission to Emergency Department at time 266.77 (Duration in Crisis Admission: 37.85)
# Client 12 moved from Awaiting Nursing Home (W2) to Nursing Home at time 268.60 (Duration in Awaiting Nursing Home (W2): 258.56)
# Client 34 to be discharged (priority trajectory) from Nursing Home at 269.05
# Client 34 moved from Nursing Home to Discharge at time 269.05 (Duration in Nursing Home: 238.35)
# Client 29 in Nursing Home, planned stay: 316.77h at 269.05
# Client 24 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 269.65 (Duration in Clinical Ward: 115.22)
# Client 24 in W2 (awaiting Nursing Home), wait: 1.97h at 269.65
# Client 88 moved from Acute Admission Unit to Awaiting Nursing Home (W2) at time 270.15 (Duration in Acute Admission Unit: 62.59)
# Client 88 in W2 (awaiting Nursing Home), wait: 67.76h at 270.15
# Client 24 moved from Awaiting Nursing Home (W2) to Nursing Home at time 271.62 (Duration in Awaiting Nursing Home (W2): 1.97)
# Client 73 moved from Awaiting Nursing Home (W2) to Nursing Home at time 271.96 (Duration in Awaiting Nursing Home (W2): 27.15)
# Client 64 moved from Awaiting Nursing Home (W2) to Nursing Home at time 274.19 (Duration in Awaiting Nursing Home (W2): 33.32)
# Client 56 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 278.37 (Duration in Clinical Ward: 86.41)
# Client 56 in W2 (awaiting Nursing Home), wait: 30.52h at 278.37
# Client 85 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 278.93 (Duration in Clinical Ward: 92.97)
# Client 85 in W2 (awaiting Nursing Home), wait: 50.60h at 278.93
# Client 75 moved from Awaiting Nursing Home (W2) to Nursing Home at time 279.74 (Duration in Awaiting Nursing Home (W2): 94.43)
# Client 42 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 285.42 (Duration in Clinical Ward: 134.32)
# Client 42 in W2 (awaiting Nursing Home), wait: 118.93h at 285.42
# Client 78 moved from Emergency Department to Awaiting Nursing Home (W2) at time 290.77 (Duration in Emergency Department: 23.99)
# Client 78 in W2 (awaiting Nursing Home), wait: 9.61h at 290.77
# Client 67 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 291.92 (Duration in Clinical Ward: 50.87)
# Client 67 in W2 (awaiting Nursing Home), wait: 42.25h at 291.92
# Client 80 moved from Awaiting Nursing Home (W2) to Nursing Home at time 295.03 (Duration in Awaiting Nursing Home (W2): 56.01)
# Client 41 moved from Awaiting Nursing Home (W2) to Nursing Home at time 299.59 (Duration in Awaiting Nursing Home (W2): 94.24)
# Client 78 moved from Awaiting Nursing Home (W2) to Nursing Home at time 300.38 (Duration in Awaiting Nursing Home (W2): 9.61)
# Client 66 moved from Awaiting Nursing Home (W2) to Nursing Home at time 300.83 (Duration in Awaiting Nursing Home (W2): 135.90)
# Client 56 moved from Awaiting Nursing Home (W2) to Nursing Home at time 308.89 (Duration in Awaiting Nursing Home (W2): 30.52)
# Client 14 to be discharged (priority trajectory) from Nursing Home at 312.74
# Client 14 moved from Nursing Home to Discharge at time 312.74 (Duration in Nursing Home: 297.83)
# Client 45 in Nursing Home, planned stay: 439.43h at 312.74
# Client 85 moved from Awaiting Nursing Home (W2) to Nursing Home at time 329.52 (Duration in Awaiting Nursing Home (W2): 50.60)
# Client 35 moved from Awaiting Nursing Home (W2) to Nursing Home at time 329.58 (Duration in Awaiting Nursing Home (W2): 310.67)
# Client 99 to be discharged (regular trajectory) from Nursing Home at 332.34
# Client 99 moved from Nursing Home to Discharge at time 332.34 (Duration in Nursing Home: 275.33)
# Client 65 in Nursing Home, planned stay: 360.07h at 332.34
# Client 67 moved from Awaiting Nursing Home (W2) to Nursing Home at time 334.17 (Duration in Awaiting Nursing Home (W2): 42.25)
# Client 93 moved from Clinical Ward to Awaiting Nursing Home (W2) at time 337.40 (Duration in Clinical Ward: 129.95)
# Client 93 in W2 (awaiting Nursing Home), wait: 19.46h at 337.40
# Client 88 moved from Awaiting Nursing Home (W2) to Nursing Home at time 337.91 (Duration in Awaiting Nursing Home (W2): 67.76)
# Client 26 to be discharged (priority trajectory) from Nursing Home at 340.93
# Client 26 moved from Nursing Home to Discharge at time 340.93 (Duration in Nursing Home: 312.60)
# Client 50 in Nursing Home, planned stay: 641.47h at 340.93
# Client 16 moved from Awaiting Nursing Home (W2) to Nursing Home at time 345.24 (Duration in Awaiting Nursing Home (W2): 86.77)
# Client 17 to be discharged (regular trajectory) from Nursing Home at 347.76
# Client 17 moved from Nursing Home to Discharge at time 347.76 (Duration in Nursing Home: 320.73)
# Client 27 in Nursing Home, planned stay: 550.91h at 347.76
# Client 93 moved from Awaiting Nursing Home (W2) to Nursing Home at time 356.86 (Duration in Awaiting Nursing Home (W2): 19.46)
# Client 11 moved from Awaiting Nursing Home (W2) to Nursing Home at time 376.34 (Duration in Awaiting Nursing Home (W2): 137.23)
# Client 92 to be discharged (regular trajectory) from Nursing Home at 376.91
# Client 92 moved from Nursing Home to Discharge at time 376.91 (Duration in Nursing Home: 326.38)
# Client 94 in Nursing Home, planned stay: 689.75h at 376.91
# Client 58 to be discharged (priority trajectory) from Nursing Home at 387.13
# Client 58 moved from Nursing Home to Discharge at time 387.13 (Duration in Nursing Home: 338.73)
# Client 98 in Nursing Home, planned stay: 471.65h at 387.13
# Client 42 moved from Awaiting Nursing Home (W2) to Nursing Home at time 404.36 (Duration in Awaiting Nursing Home (W2): 118.93)
# Client 13 moved from Awaiting Nursing Home (W2) to Nursing Home at time 407.56 (Duration in Awaiting Nursing Home (W2): 156.86)
# Client 20 moved from Awaiting Nursing Home (W2) to Nursing Home at time 426.22 (Duration in Awaiting Nursing Home (W2): 244.92)
# Client 62 to be discharged (regular trajectory) from Nursing Home at 452.15
# Client 62 moved from Nursing Home to Discharge at time 452.15 (Duration in Nursing Home: 396.77)
# Client 32 in Nursing Home, planned stay: 341.61h at 452.15
# Client 44 to be discharged (regular trajectory) from Nursing Home at 468.10
# Client 44 moved from Nursing Home to Discharge at time 468.10 (Duration in Nursing Home: 406.20)
# Client 82 in Nursing Home, planned stay: 703.54h at 468.10
# Client 53 to be discharged (regular trajectory) from Nursing Home at 498.42
# Client 53 moved from Nursing Home to Discharge at time 498.42 (Duration in Nursing Home: 469.17)
# Client 84 in Nursing Home, planned stay: 452.06h at 498.42
# Client 15 to be discharged (priority trajectory) from Nursing Home at 499.55
# Client 15 moved from Nursing Home to Discharge at time 499.55 (Duration in Nursing Home: 440.90)
# Client 57 in Nursing Home, planned stay: 531.03h at 499.55
# Client 6 to be discharged (priority trajectory) from Nursing Home at 556.67
# Client 6 moved from Nursing Home to Discharge at time 556.67 (Duration in Nursing Home: 538.77)
# Client 74 in Nursing Home, planned stay: 396.11h at 556.67
# Client 68 to be discharged (regular trajectory) from Nursing Home at 571.15
# Client 68 moved from Nursing Home to Discharge at time 571.15 (Duration in Nursing Home: 515.63)
# Client 40 in Nursing Home, planned stay: 367.70h at 571.15
# Client 8 to be discharged (priority trajectory) from Nursing Home at 577.80
# Client 8 moved from Nursing Home to Discharge at time 577.80 (Duration in Nursing Home: 556.35)
# Client 77 in Nursing Home, planned stay: 513.23h at 577.80
# Client 29 to be discharged (priority trajectory) from Nursing Home at 585.82
# Client 29 moved from Nursing Home to Discharge at time 585.82 (Duration in Nursing Home: 518.94)
# Client 71 in Nursing Home, planned stay: 280.36h at 585.82
# Client 2 to be discharged (priority trajectory) from Nursing Home at 638.25
# Client 2 moved from Nursing Home to Discharge at time 638.25 (Duration in Nursing Home: 607.46)
# Client 51 in Nursing Home, planned stay: 680.08h at 638.25
# Client 18 to be discharged (regular trajectory) from Nursing Home at 638.99
# Client 18 moved from Nursing Home to Discharge at time 638.99 (Duration in Nursing Home: 602.63)
# Client 96 in Nursing Home, planned stay: 553.43h at 638.99
# Client 89 to be discharged (regular trajectory) from Nursing Home at 641.70
# Client 89 moved from Nursing Home to Discharge at time 641.70 (Duration in Nursing Home: 582.53)
# Client 47 in Nursing Home, planned stay: 705.18h at 641.70
# Client 46 to be discharged (priority trajectory) from Nursing Home at 655.96
# Client 46 moved from Nursing Home to Discharge at time 655.96 (Duration in Nursing Home: 618.76)
# Client 87 in Nursing Home, planned stay: 300.09h at 655.96
# Client 1 to be discharged (regular trajectory) from Nursing Home at 689.38
# Client 1 moved from Nursing Home to Discharge at time 689.38 (Duration in Nursing Home: 654.54)
# Client 30 in Nursing Home, planned stay: 472.06h at 689.38
# Client 65 to be discharged (priority trajectory) from Nursing Home at 692.41
# Client 65 moved from Nursing Home to Discharge at time 692.41 (Duration in Nursing Home: 624.53)
# Client 48 in Nursing Home, planned stay: 219.45h at 692.41
# Client 79 to be discharged (priority trajectory) from Nursing Home at 709.07
# Client 79 moved from Nursing Home to Discharge at time 709.07 (Duration in Nursing Home: 648.10)
# Client 19 in Nursing Home, planned stay: 671.94h at 709.07
# Client 45 to be discharged (regular trajectory) from Nursing Home at 752.18
# Client 45 moved from Nursing Home to Discharge at time 752.18 (Duration in Nursing Home: 685.23)
# Client 33 in Nursing Home, planned stay: 232.84h at 752.18
# Client 32 to be discharged (priority trajectory) from Nursing Home at 793.77
# Client 32 moved from Nursing Home to Discharge at time 793.77 (Duration in Nursing Home: 714.04)
# Client 54 in Nursing Home, planned stay: 443.10h at 793.77
# Client 98 to be discharged (priority trajectory) from Nursing Home at 858.78
# Client 98 moved from Nursing Home to Discharge at time 858.78 (Duration in Nursing Home: 781.27)
# Client 90 in Nursing Home, planned stay: 448.90h at 858.78
# Client 71 to be discharged (regular trajectory) from Nursing Home at 866.18
# Client 71 moved from Nursing Home to Discharge at time 866.18 (Duration in Nursing Home: 757.94)
# Client 25 in Nursing Home, planned stay: 628.77h at 866.18
# Client 27 to be discharged (priority trajectory) from Nursing Home at 898.67
# Client 27 moved from Nursing Home to Discharge at time 898.67 (Duration in Nursing Home: 827.72)
# Client 39 in Nursing Home, planned stay: 302.54h at 898.67
# Client 48 to be discharged (priority trajectory) from Nursing Home at 911.86
# Client 48 moved from Nursing Home to Discharge at time 911.86 (Duration in Nursing Home: 786.43)
# Client 28 in Nursing Home, planned stay: 379.74h at 911.86
# Client 40 to be discharged (priority trajectory) from Nursing Home at 938.86
# Client 40 moved from Nursing Home to Discharge at time 938.86 (Duration in Nursing Home: 845.37)
# Client 36 in Nursing Home, planned stay: 448.55h at 938.86
# Client 84 to be discharged (priority trajectory) from Nursing Home at 950.48
# Client 84 moved from Nursing Home to Discharge at time 950.48 (Duration in Nursing Home: 864.39)
# Client 70 in Nursing Home, planned stay: 644.94h at 950.48
# Client 74 to be discharged (regular trajectory) from Nursing Home at 952.78
# Client 74 moved from Nursing Home to Discharge at time 952.78 (Duration in Nursing Home: 865.11)
# Client 72 in Nursing Home, planned stay: 604.08h at 952.78
# Client 87 to be discharged (regular trajectory) from Nursing Home at 956.05
# Client 87 moved from Nursing Home to Discharge at time 956.05 (Duration in Nursing Home: 834.57)
# Client 7 in Nursing Home, planned stay: 683.71h at 956.05
# Client 50 to be discharged (priority trajectory) from Nursing Home at 982.39
# Client 50 moved from Nursing Home to Discharge at time 982.39 (Duration in Nursing Home: 912.19)
# Client 76 in Nursing Home, planned stay: 620.94h at 982.39
# Client 33 to be discharged (regular trajectory) from Nursing Home at 985.02
# Client 33 moved from Nursing Home to Discharge at time 985.02 (Duration in Nursing Home: 850.14)
# Client 59 in Nursing Home, planned stay: 332.80h at 985.02
#
# --- Simulation ended at time 1000.00 ---
# 61 out of 100 clients were still active (not Discharged or Passed Away) at SIM_TIME.
#
# === Simulation Statistics Summary ===
#
# Number of visits to each state:
# Home: 100 visits
# Emergency Department: 62 visits
# General Practitioner: 47 visits
# Awaiting Nursing Home (W2): 97 visits
# Geriatric Rehabilitation: 15 visits
# Nursing Home: 97 visits
# Crisis Admission: 28 visits
# Short-Term Residential Care: 13 visits
# Acute Admission Unit: 12 visits
# Clinical Ward: 23 visits
# Discharge: 36 visits
#
# Average time spent in each state (for clients who completed their stay there):
# Acute Admission Unit: 46.56 hours (based on 12 entries)
# Awaiting Nursing Home (W2): 54.70 hours (based on 97 entries)
# Clinical Ward: 93.50 hours (based on 23 entries)
# Crisis Admission: 55.63 hours (based on 28 entries)
# Emergency Department: 28.60 hours (based on 62 entries)
# General Practitioner: 47.83 hours (based on 47 entries)
# Geriatric Rehabilitation: 47.00 hours (based on 15 entries)
# Home: 24.55 hours (based on 50 entries)
# Nursing Home: 695.68 hours (based on 97 entries)
# Short-Term Residential Care: 51.59 hours (based on 13 entries)
#
# Average capacity usage (occupancy) per state:
# Acute Admission Unit: Avg 0.56 clients (Max: 7, Capacity: 10)
# Clinical Ward: Avg 1.86 clients (Max: 10, Capacity: 10)
# Crisis Admission: Avg 1.38 clients (Max: 10, Capacity: 10)
# Emergency Department: Avg 0.93 clients (Max: 15, Capacity: 15)
# General Practitioner: Avg 1.19 clients (Max: 10, Capacity: 10)
# Geriatric Rehabilitation: Avg 0.70 clients (Max: 8, Capacity: 10)
# Nursing Home: Avg 19.25 clients (Max: 20, Capacity: 20)
# Short-Term Residential Care: Avg 0.67 clients (Max: 8, Capacity: 10)
#
# Transition counts between states:
# Acute Admission Unit -> Awaiting Nursing Home (W2): 12 transitions
# Awaiting Nursing Home (W2) -> Nursing Home: 97 transitions
# Clinical Ward -> Awaiting Nursing Home (W2): 23 transitions
# Crisis Admission -> Acute Admission Unit: 6 transitions
# Crisis Admission -> Clinical Ward: 13 transitions
# Crisis Admission -> Emergency Department: 5 transitions
# Crisis Admission -> Geriatric Rehabilitation: 4 transitions
# Emergency Department -> Awaiting Nursing Home (W2): 62 transitions
# General Practitioner -> Crisis Admission: 25 transitions
# General Practitioner -> Geriatric Rehabilitation: 11 transitions
# General Practitioner -> Short-Term Residential Care: 11 transitions
# Geriatric Rehabilitation -> Acute Admission Unit: 1 transitions
# Geriatric Rehabilitation -> Clinical Ward: 6 transitions
# Geriatric Rehabilitation -> Crisis Admission: 2 transitions
# Geriatric Rehabilitation -> Emergency Department: 4 transitions
# Geriatric Rehabilitation -> Short-Term Residential Care: 2 transitions
# Home -> Emergency Department: 50 transitions
# Home -> General Practitioner: 47 transitions
# Home -> Passed Away: 3 transitions
# Nursing Home -> Discharge: 36 transitions
# Short-Term Residential Care -> Acute Admission Unit: 5 transitions
# Short-Term Residential Care -> Clinical Ward: 4 transitions
# Short-Term Residential Care -> Crisis Admission: 1 transitions
# Short-Term Residential Care -> Emergency Department: 3 transitions
#
# Final states of clients at SIM_TIME or upon exit:
# Discharge: 36 clients
# Nursing Home: 61 clients
# Passed Away: 3 clients
#
# Total clients who passed away: 3
# Percentage of clients who passed away: 3.00%

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import webbrowser
from datetime import datetime, timedelta
import pandas as pd
import folium
import colorsys

# 1) Initialize Firebase
cred = credentials.Certificate('healthy-healthcare-firebase-adminsdk-fbsvc-05315e3efc.json')
if not firebase_admin._apps:
    firebase_admin.initialize_app(cred)
db = firestore.client()

# 2) Helper: map performance ratio to semi-transparent RGBA color (green->red)
def perf_color(ratio, alpha=0.6):
    ratio = max(0, min(1, ratio))
    # Hue from red (0°) to green (120°)
    h = (120 * ratio) / 360
    r, g, b = colorsys.hls_to_rgb(h, 0.5, 1)
    return f'rgba({int(r*255)}, {int(g*255)}, {int(b*255)}, {alpha})'

# 3) CSS for dashboard: centered layout, rectangular tiles, side-by-side regions
box_css = '''
body {
  margin: 0;
  font-family: sans-serif;
  display: flex;
  flex-direction: column;
  align-items: center;
}
.regions-container {
  display: flex;
  flex-direction: row;
  justify-content: center;
  gap: 150px;
  flex-wrap: wrap;
}
.region {
  width: 380px;
  margin: 20px;
}
.region h2 {
  text-align: center;
  margin: 0 0 10px;
  font-size: 2em;
  font-weight: 700;
}
.grid {
  display: grid;
  grid-template-columns: repeat(3, 140px);
  grid-template-rows: repeat(3, 100px);
  grid-auto-flow: column;
  justify-content: center;
  gap: 10px;
}
.tile {
  width: 140px;
  height: 100px;
  display: flex;
  flex-direction: column;
  justify-content: center;
  align-items: center;
  border: 2px solid #000;
  border-radius: 8px;
  padding: 4px;
  color: #000;
}
.tile h3 {
  margin: 0 0 4px;
  font-size: 0.8em;
  font-weight: 600;
}
.tile p {
  margin: 0;
  font-size: 1em;
  font-weight: 700;
}
.button-container {
  text-align: center;
  margin: 30px 0;
}
.button-container button {
  padding: 12px 24px;
  font-size: 1.2em;
  border: none;
  background-color: #333;
  color: #fff;
  border-radius: 4px;
  cursor: pointer;
}
.button-container button:hover {
  background-color: #555;
}
'''

# 4) Build dashboard HTML
today = datetime.now()
base_date = datetime(2025, 5, 1)
week = 1
doc_key = (base_date + timedelta(weeks=week)).strftime('%Y-%m-%d')
municipalities = ['Arnhem', 'Nijmegen']

# Start HTML
dashboard_html = f"""<!DOCTYPE html>
<html>
<head>
  <style>{box_css}</style>
</head>
<body>
  <div class='regions-container'>
"""

# Gather max wait to normalize
waits = []
for city in municipalities:
    doc = db.collection('prediction').document(city).collection('weeks').document(f'week_{doc_key}').get()
    m = doc.to_dict().get('metrics', {})
    waits += [m.get('WAIT_W2', 0), m.get('WAIT_ELV', 0), m.get('WAIT_CRISIS', 0)]
max_wait = max(waits) if waits else 1

# Render each region side by side
for city in municipalities:
    doc = db.collection('prediction').document(city).collection('weeks').document(f'week_{doc_key}').get()
    m = doc.to_dict().get('metrics', {})
    # compute metrics
    nh_beds = m.get('NHBEDS', 0)
    nh_occ = m.get('OCC_NH', 0)
    nh_wait = m.get('WAIT_W2', 0)
    nh_avail = nh_beds * (1 - nh_occ)
    elv_beds = m.get('ELVBEDS', 0)
    elv_occ = m.get('OCC_ELV', 0)
    elv_wait = m.get('WAIT_ELV', 0)
    elv_avail = elv_beds * (1 - elv_occ)
    cr_beds = m.get('CRISISBEDS', 0)
    cr_occ = m.get('OCC_CRISIS', 0)
    cr_wait = m.get('WAIT_CRISIS', 0)
    cr_avail = cr_beds * (1 - cr_occ)
    # performance ratios
    ratios = {
        'nh_avail': nh_avail/nh_beds if nh_beds else 0,
        'nh_occ': 1-nh_occ,
        'nh_wait': 1-(nh_wait/max_wait),
        'elv_avail': elv_avail/elv_beds if elv_beds else 0,
        'elv_occ': 1-elv_occ,
        'elv_wait': 1-(elv_wait/max_wait),
        'cr_avail': cr_avail/cr_beds if cr_beds else 0,
        'cr_occ': 1-cr_occ,
        'cr_wait': 1-(cr_wait/max_wait)
    }
    dashboard_html += f"""
    <div class='region'>
      <h2>{city}</h2>
      <div class='grid'>
        <div class='tile' style='background:{perf_color(ratios['nh_avail'])}'>
          <h3>NH Available beds</h3><p>{int(nh_avail)}/{nh_beds}</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['nh_occ'])}'>
          <h3>NH Occupcancy Rate</h3><p>{nh_occ*100:.1f}%</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['nh_wait'])}'>
          <h3>NH Waiting time</h3><p>{nh_wait:.1f}d</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['elv_avail'])}'>
          <h3>ELV Available beds</h3><p>{int(elv_avail)}/{elv_beds}</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['elv_occ'])}'>
          <h3>ELV Occupancy rate</h3><p>{elv_occ*100:.1f}%</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['elv_wait'])}'>
          <h3>ELV Waiting time</h3><p>{elv_wait:.1f}d</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['cr_avail'])}'>
          <h3>Crisis Available beds</h3><p>{int(cr_avail)}/{cr_beds}</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['cr_occ'])}'>
          <h3>Crisis Occupancy rate</h3><p>{cr_occ*100:.1f}%</p>
        </div>
        <div class='tile' style='background:{perf_color(ratios['cr_wait'])}'>
          <h3>Crisis Waiting time</h3><p>{cr_wait:.1f}d</p>
        </div>
      </div>
    </div>
"""
# Close regions container and add button

dashboard_html += f"""
  </div>  <!-- .regions-container -->
  <div class='button-container'>
    <button onclick="window.location.href='map.html'">View Map of Facilities</button>
  </div>
</body>
</html>
"""

with open('dashboard.html', 'w') as f:
    f.write(dashboard_html)
webbrowser.open('dashboard.html')

# 5) Map code unchanged follows her

# ─── 4) (mapping code unchanged) ─────────────────────────────────────
# ... your existing map-building logic follows here ..
map_rows = []
for city in municipalities:
    doc = db.collection('prediction')\
             .document(city)\
             .collection('weeks')\
             .document(f'week_{doc_key}').get()
    data = doc.to_dict() if doc.exists else {"active_patients_data":[], "metrics":{}}
    m = data.get('metrics', {})
    map_rows.append({
        'place_name':    city,
        'type':          'Municipality',
        'municipality':  city,
        'lat':           municipality_info[city]['lat'],
        'lon':           municipality_info[city]['lon'],
        'beds':          m.get('NHBEDS',0),
        'active_total':  len(data.get('active_patients_data',[])),
        'occupancy_tot': m.get('OCC_NH',0),
        'wait_tot':      m.get('WAIT_W2',0)
    })

# 4b) load nursing homes from CSVs
df_arn = pd.read_csv('arnhem.csv', dtype={'Postcode': str}); df_arn['municipality']='Arnhem'
df_nij = pd.read_csv('nijmegen.csv', dtype={'Postcode': str}); df_nij['municipality']='Nijmegen'
df_nh  = pd.concat([df_arn, df_nij], ignore_index=True)
# normalize to 6-char code
df_nh['Postcode_norm'] = (
    df_nh['Postcode'].str.upper()
           .str.replace(r"\s+","",regex=True)
 )

# 4c) load or cache full Dutch postcode CSV locally to speed future runs
pc_url = 'https://raw.githubusercontent.com/fatahfattah/6pp/main/6pp.csv'
cache_path = pathlib.Path('6pp.csv')
if not cache_path.exists():
    df_pc_full = pd.read_csv(pc_url, usecols=['postcode','latitude','longitude'], dtype=str)
    df_pc_full.to_csv(cache_path, index=False)
else:
    df_pc_full = pd.read_csv(cache_path, usecols=['postcode','latitude','longitude'], dtype=str)
# normalize postal codes in full dataset
df_pc_full['postcode_norm'] = (
    df_pc_full['postcode'].str.upper()
               .str.replace(r"\s+","",regex=True)
 )
postcode_map = {
    r['postcode_norm']: (float(r['latitude']), float(r['longitude']))
    for _,r in df_pc_full.iterrows()
}

# 4d) assign coords for nursing homes
def get_coords(pc, town):
    coords = postcode_map.get(pc)
    if coords:
        return coords
    return (municipality_info[town]['lat'], municipality_info[town]['lon'])

for _, row in df_nh.iterrows():
    lat, lon = get_coords(row['Postcode_norm'], row['municipality'])
    map_rows.append({
        'place_name':    row['Naam'],
        'type':          'Nursing Home',
        'municipality':  row['municipality'],
        'lat':           lat,
        'lon':           lon,
        'beds':          row.get('Aantal Plaatsen Totaal',0),
        'active_total':  None,
        'occupancy_tot': None,
        'wait_tot':      None
    })

# 4e) pro-rata distribution
df_map = pd.DataFrame(map_rows)
beds_by_city = df_map.groupby('municipality')['beds'].sum()
metrics = {}
for city in municipalities:
    base = df_map.query("municipality==@city and type=='Municipality'").iloc[0]
    metrics[city] = {
        'active':    base['active_total'],
        'occupancy': base['occupancy_tot'],
        'wait':      base['wait_tot']
    }
def dist_active(r):
    if r['type']=='Municipality': return metrics[r['municipality']]['active']
    return round(metrics[r['municipality']]['active'] * (r['beds']/beds_by_city[r['municipality']]))

df_map['active_patients'] = df_map.apply(dist_active, axis=1)
df_map['occupancy_rate']   = df_map['municipality'].map(lambda c: metrics[c]['occupancy'])
df_map['wait_days']        = df_map['municipality'].map(lambda c: metrics[c]['wait'])

# 4f) render folium map
g = folium.Map(location=[51.85, 5.9], zoom_start=10)
def marker_color(t): return 'red' if t == 'Municipality' else 'blue'

for _, r in df_map.iterrows():
    available_beds = int(r['beds'] * (1 - r['occupancy_rate']))
    popup_html = (
        f"<b>{r['place_name']}</b><br>"
        f"Available Beds: {available_beds}<br>"
        f"Active Patients: {r['active_patients']}<br>"
        f"Occupancy Rate: {r['occupancy_rate']*100:.1f}%<br>"
        f"Waiting Time: {r['wait_days']:.1f} days"
    )
    folium.Marker(
        [r['lat'], r['lon']],
        tooltip=r['place_name'],
        popup=folium.Popup(popup_html, max_width=300),
        icon=folium.Icon(color=marker_color(r['type']))
    ).add_to(g)

g.save('map.html')
